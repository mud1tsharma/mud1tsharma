# %%
import requests
import os
import re
import json
import csv
import pandas as pd
import numpy as np
import math
import html
pd.set_option("display.min_rows", 50)

# %%
# Save my persona; GENESIS username and password
username = 'DE7UN14YCR'
password = 'jydhit-fiZja0'

# %%
# Does a topics file exist?
try:
    topics = pd.read_csv('topics.csv')

# If not, create one
except:
    
    topicsURL = 'https://www-genesis.destatis.de/genesisWS/rest/2020/catalogue/statistics?username={}&password={}&selection=*&area=all&&pagelength=25000&language=en'.format(username, password)
    topics = [item['Code'] for item in requests.get(topicsURL).json()['List']]
    df = pd.DataFrame(topics, columns = ['Topic'])
    df.to_csv('topics.csv', index = False)
    
topics = list(topics['Topic'])

# %%
print ('There are {} topics. Here are the first 3:{}{}'.format(len(topics), '\n', topics[:3]))
# Out:
# There are 306 topics. Here are the first 3:
# [11111, 12111, 12211]

# %%
def Timeseries (topic):
        
    timeseriesURL = 'https://www-genesis.destatis.de/genesisWS/rest/2020/catalogue/tables?username={}&password={}&selection={}*&area=all&pagelength=2500&language=en'.format(username, password, topic)
    timeseries = [[item['Code'],item['Content']] for item in requests.get(timeseriesURL).json()['List'] if item['Time'] and item['Time'].split(' to ')[0] != item['Time'].split(' to ')[1]]
    
    timeDims = [['Year'], ['Reference month'], ['Reference date'],'Year','Reference month','Reference date']
    
    result = []
    for item in timeseries:
        
        transpose = []
    
        metadata = 'https://www-genesis.destatis.de/genesisWS/rest/2020/metadata/table?username={}&password={}&name={}&area=all&language=en'.format(username, password, item[0])
        metadata = requests.get(metadata).json()['Object']

        rows = metadata['Structure']['Rows']
        columns = metadata['Structure']['Columns']

        # If the metadata contains row information:
        rowItems = []

        if rows:
            # Parse individual row names
            rowItems.append([row['Content'] for row in rows])

        else:
            rowItems.append('-')

        rowItems = rowItems[0]

        columnItems = []

        # If the metadata contains column information:
        if columns:
            columnItems.append([column['Content'] for column in columns])

        else:
            columnItems.append('-')

        columnItems = columnItems[0]

        rowsColumns = rowItems + columnItems
        
        if not any(name in rowsColumns for name in timeDims):
            continue
            
        elif any(name in columnItems for name in timeDims):
            result += [[item[0],item[1],False]]
            continue 
            
        else:
            result += [[item[0],item[1],True]]

    return result

# %%
# WARNING - THIS CELL TAKES >1 HOUR TO RUN

# Does a catalog file exist?
try:
    catalog = pd.read_csv('catalog.csv')

# If not, create one
except:
    
    catalog = []
    
    for topic in topics:
    
        timeseriesURL = 'https://www-genesis.destatis.de/genesisWS/rest/2020/catalogue/tables?username={}&password={}&selection={}*&area=all&pagelength=2500&language=en'.format(username, password, topic)
        catalog += Timeseries (topic)
        print (topic)

    df = pd.DataFrame(catalog, columns = ['ID','Name','Transpose'])
    df.to_csv('catalog.csv', index = False)

# %%
print ('There are {} tables. Here are the first 5:{}{}'.format(len(catalog), '\n', catalog.head()))
# Out:
# There are 1175 tables. Here are the first 5:
#            ID                                               Name  Transpose
# 0  11111-0001          Size of territory: Länder, reference date      False
# 1  11111-0002  Size of territory: Administrative districts, r...      False
# 2  12211-9000  Population, persons in employment, unemployed ...       True
# 3  12211-9001  Population, persons in employment, unemployed ...       True
# 4  12211-9002  Population, persons in employment, unemployed ...       True

# %%
### AUXILLIARY FUNCTIONS ###

def Metadata (item):
    
    # Metadata URLs in English and German (used later for translating row labels)
    metadata = 'https://www-genesis.destatis.de/genesisWS/rest/2020/metadata/table?username={}&password={}&name={}&area=all&language={}'.format(username, password, item, 'en')
    metadataDe = 'https://www-genesis.destatis.de/genesisWS/rest/2020/metadata/table?username={}&password={}&name={}&area=all&language={}'.format(username, password, item, 'de')
    
    # Call both URLs
    metadata = requests.get(metadata).json()['Object']
    metadataDe = requests.get(metadataDe).json()['Object']
    
    # Define a dictionary for metadata information
    Index = {'Resource ID':'', 'Resource Name':'', 'Date From':'', 'Date To':'', 'Rows':'', 'Columns':''}
    
    # Input 4 of 6 metadata
    Index['Resource ID'] = metadata['Code']
    Index['Resource Name'] = metadata['Content']
    Index['Date From'] = metadata['Time']['From']
    Index['Date To'] = metadata['Time']['To']
    
    items = []
    rows = metadata['Structure']['Rows']
    
    # If the metadata contains row information:
    if rows:
        
        # Parse individual row names
        items.append([item['Content'] for item in rows])
        
        # Parse individual row names in German
        rowsDe = [item['Content'] for item in metadataDe['Structure']['Rows']]
    
    else:
        items.append('-')
    
    # Append row information to the Index dictionary
    Index['Rows'] = items[0]
    
    # Create a translation dictionary to translate German row labels into English (where possible)
    translation = dict(zip(rowsDe, Index['Rows']))
                     
    items = []
    columns = metadata['Structure']['Columns']
    
    # If the metadata contains column information:
    if columns:
        items.append([item['Content'] for item in columns])
    
    else:
        items.append('-')

    Index['Columns'] = items[0]
    
    # Create a DataFrame with the extracted metadata information
    df = pd.DataFrame.from_dict(Index, orient = 'index', columns = [''])
    
    # Return the df, and the translation dictionary
    return (df, translation)


# Function to splice a DataFrame to exclude metadata, such as the organisation's name or databank's name
def DF (df):

    # Starting from the first row
    beginning = 0
    
    # Iterate through each row
    for row in df.itertuples():
        
        # If the first column in that row IS null, this indicates that this row contains column names
        if pd.isnull(row[1]):
            break
        
        # If the first column is NOT null, this indicates that this row contains metadata
        else:
            # Increment beginning by 1, and continue the loop until the first column IS null
            beginning += 1
            continue
            
    # The last rows of the dataset may or may not contain metadata, so we repeat this process
    end = len(df)
    
    # Iterate through each row from the end of the DataFrame
    for row in df[::-1].itertuples():
        
        # If the first column IS null, it does not contain a row label
        if pd.isnull(row[-1]):
            
            # Decrement end by 1, and continue the loop until the first column is NOT null
            end -= 1
            continue
        
        else:
            break
    
    # Return the spliced DataFrame, removing other NaN values
    df = df.iloc[beginning:end,:]
    df = df.replace(np.nan, '')
    
    return df

def RowFixer (row):
    
    replacement = ''
    
    for index in range(len(row)):
        
        if pd.isnull(row[index]):
            row[index] = replacement
        
        else:
            replacement = row[index]
    
    return row

def ColumnFixer (df):
    
    drops = []
    
    for index,row in df.iterrows():
        
        if pd.isnull(row[0]):
            
            df.iloc[index,:] = RowFixer(row)
            
    df = df.reset_index(drop=True)
                                    
    for index,row in df.iterrows():
        
        if len(set(row)) == 2:
            df.drop(index, inplace = True)
            
    df = df.reset_index(drop=True)
                
    for column in [column for column in df.columns if column != '']:
        
        try:
            df[column] = pd.to_numeric(df[column])
        
        except:
            pass
        
        try:
            df[column] = df[column].str.replace(',','.')
            df[column] = df[column].replace('-','').replace('.','')
            df[column] = pd.to_numeric(df[column])
        
        except:
            pass
    
    multiIndex = []
    Index = 0
    
    for index,row in df.iterrows():
        
        if df.iloc[index,0] == '':
            
            multiIndex.append(list(row))
            Index+=1
            
            if Index == 2:
                
                multiIndex = pd.MultiIndex.from_arrays(multiIndex)
                df.columns = multiIndex

                return df.iloc[Index:,:].reset_index(drop=True)
            
    return df.iloc[Index:,:].reset_index(drop=True)

# %%
def CSV (item, metadata, translation, transpose):
        
    # URL of the timeseries
    resourceURL = 'https://www-genesis.destatis.de/genesisWS/rest/2020/data/tablefile?username={}&password={}&name={}&area=all&transpose={}&startyear=1900&endyear=2100&format=csv&language=en'.format(username,password,item,transpose)    
    
    df = pd.read_csv (resourceURL, delimiter = ';').reset_index()
    
    rows = metadata.loc['Rows',:][0]
    
    df = DF (df)
    
    Index = []
    
    for item in df.iloc[:,0]:
        
        try:
            item = item.replace('nachr.: ','')
            item = translation[item.strip()]
            Index.append(item)
        
        except KeyError:
            Index.append(item.strip())
                
    df.iloc[:,0] = Index     
    df.columns = df.iloc[0,:]
    df = df.iloc[1:,:].reset_index().drop(columns = ['index'])
    
    return ColumnFixer(df)

# %%
for timeseries in catalog.iterrows():
    
    topic = timeseries[1][0].split('-')[0]
    
    try:
        metadata,translation = Metadata (timeseries[1][0])
        df = CSV(timeseries[1][0], metadata, translation, timeseries[1][2])
    
    except Exception as exception:
        print (timeseries[1][0],exception)
        continue

    path = os.path.join(os.getcwd(), topic, timeseries[1][0])

    if not os.path.exists(path):
        os.makedirs(path)

    csvpath = '{}/data.csv'.format(path)
    df.to_csv(csvpath, index = False)

    metadatapath = '{}/metadata.csv'.format(path)
    metadata.to_csv(metadatapath, index = True)

    print (timeseries[1][0],'-',path)
# Out:
# 11111-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/11111/11111-0001
# 11111-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/11111/11111-0002
# 12211-9000 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9000
# 12211-9001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9001
# 12211-9002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9002
# 12211-9003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9003
# 12211-9004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9004
# 12211-9005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9005
# 12211-9006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9006
# 12211-9007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9007
# 12211-9008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9008
# 12211-9009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9009
# 12211-9010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9010
# 12211-9011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9011
# 12211-9016 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9016
# 12211-9017 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9017
# 12211-9018 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9018
# 12211-9019 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9019
# 12211-9020 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9020
# 12211-9021 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9021
# 12211-9022 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9022
# 12211-9023 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9023
# 12211-9024 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9024
# 12211-9025 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9025
# 12211-9026 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9026
# 12211-9027 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9027
# 12211-9028 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9028
# 12211-9029 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9029
# 12211-9030 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9030
# 12211-9031 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9031
# 12211-9032 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9032
# 12211-9033 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9033
# 12211-9034 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9034
# 12211-9035 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9035
# 12211-9036 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9036
# 12211-9037 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9037
# 12211-9038 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9038
# 12211-9039 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9039
# 12211-9040 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9040
# 12211-9041 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9041
# 12211-9043 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9043
# 12211-9044 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9044
# 12211-9045 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9045
# 12211-9046 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9046
# 12211-9047 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9047
# 12211-9048 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9048
# 12211-9049 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9049
# 12211-9050 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9050
# 12211-9051 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9051
# 12211-9052 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9052
# 12211-9053 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9053
# 12211-9055 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9055
# 12211-9056 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9056
# 12211-9057 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9057
# 12211-9058 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9058
# 12211-9059 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9059
# 12211-9060 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9060
# 12211-9061 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9061
# 12211-9062 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9062
# 12211-9063 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9063
# 12211-9064 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9064
# 12211-9065 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9065
# 12211-9066 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12211/12211-9066
# 12411-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12411/12411-0001
# 12411-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12411/12411-0002
# 12411-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12411/12411-0003
# 12411-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12411/12411-0004
# 12411-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12411/12411-0005
# 12411-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12411/12411-0010
# 12411-0015 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12411/12411-0015
# 12411-0040 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12411/12411-0040
# 12411-0050 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12411/12411-0050
# 12421-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12421/12421-0001
# 12421-0002 single positional indexer is out-of-bounds
# 12421-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12421/12421-0003
# 12421-0004 single positional indexer is out-of-bounds
# 12421-0100 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12421/12421-0100
# 12421-0101 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12421/12421-0101
# 12511-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12511/12511-0001
# 12511-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12511/12511-0011
# 12521-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12521/12521-0001
# 12521-0020 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12521/12521-0020
# 12531-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12531/12531-0001
# 12531-0020 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12531/12531-0020
# 12611-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12611/12611-0001
# 12611-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12611/12611-0002
# 12611-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12611/12611-0003
# 12611-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12611/12611-0004
# 12611-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12611/12611-0010
# 12611-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12611/12611-0011
# 12612-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0001
# 12612-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0002
# 12612-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0003
# 12612-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0004
# 12612-0008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0008
# 12612-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0009
# 12612-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0010
# 12612-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0011
# 12612-0014 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0014
# 12612-0015 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0015
# 12612-0016 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0016
# 12612-0017 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0017
# 12612-0018 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0018
# 12612-0019 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0019
# 12612-0020 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0020
# 12612-0021 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0021
# 12612-0022 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0022
# 12612-0023 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0023
# 12612-0100 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0100
# 12612-0101 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0101
# 12612-0102 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0102
# 12612-0103 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0103
# 12612-0104 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0104
# 12612-0105 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0105
# 12612-0106 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12612/12612-0106
# 12613-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12613/12613-0001
# 12613-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12613/12613-0002
# 12613-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12613/12613-0003
# 12613-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12613/12613-0005
# 12613-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12613/12613-0006
# 12613-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12613/12613-0007
# 12613-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12613/12613-0010
# 12613-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12613/12613-0011
# 12613-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12613/12613-0012
# 12613-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12613/12613-0013
# 12631-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12631/12631-0001
# 12631-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12631/12631-0002
# 12631-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12631/12631-0003
# 12631-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12631/12631-0010
# 12651-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12651/12651-0001
# 12651-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12651/12651-0002
# 12651-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12651/12651-0003
# 12661-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12661/12661-0001
# 12661-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12661/12661-0002
# 12711-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12711/12711-0001
# 12711-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12711/12711-0003
# 12711-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12711/12711-0005
# 12711-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12711/12711-0009
# 12711-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12711/12711-0010
# 12711-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12711/12711-0011
# 12711-0030 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/12711/12711-0030
# 13111-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13111/13111-0001
# 13111-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13111/13111-0002
# 13111-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13111/13111-0003
# 13111-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13111/13111-0004
# 13111-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13111/13111-0005
# 13111-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13111/13111-0006
# 13211-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0001
# 13211-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0002
# 13211-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0003
# 13211-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0004
# 13211-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0005
# 13211-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0006
# 13211-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0007
# 13211-0008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0008
# 13211-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0009
# 13211-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0010
# 13211-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0011
# 13211-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13211/13211-0012
# 13231-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13231/13231-0001
# 13231-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13231/13231-0002
# 13231-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13231/13231-0003
# 13311-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13311/13311-0001
# 13311-0002 single positional indexer is out-of-bounds
# 13321-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13321/13321-0001
# 13321-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13321/13321-0002
# 13321-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13321/13321-0003
# 13321-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13321/13321-0004
# 13321-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13321/13321-0005
# 13321-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/13321/13321-0006
# 14111-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14111/14111-0001
# 14111-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14111/14111-0002
# 14111-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14111/14111-0004
# 14121-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14121/14121-0001
# 14121-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14121/14121-0002
# 14121-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14121/14121-0003
# 14121-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14121/14121-0004
# 14121-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14121/14121-0005
# 14121-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14121/14121-0006
# 14211-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14211/14211-0001
# 14211-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/14211/14211-0002
# 21211-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21211/21211-0001
# 21211-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21211/21211-0002
# 21211-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21211/21211-0003
# 21211-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21211/21211-0004
# 21211-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21211/21211-0005
# 21211-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21211/21211-0006
# 21211-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21211/21211-0007
# 21211-0008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21211/21211-0008
# 21211-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21211/21211-0009
# 21231-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21231/21231-0001
# 21231-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21231/21231-0002
# 21321-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21321/21321-0001
# 21321-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21321/21321-0005
# 21341-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21341/21341-0001
# 21341-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21341/21341-0002
# 21341-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21341/21341-0003
# 21351-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21351/21351-0001
# 21351-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21351/21351-0002
# 21351-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21351/21351-0003
# 21371-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21371/21371-0001
# 21381-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21381/21381-0001
# 21381-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21381/21381-0002
# 21381-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21381/21381-0003
# 21381-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21381/21381-0004
# 21381-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21381/21381-0005
# 21381-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21381/21381-0010
# 21381-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21381/21381-0011
# 21381-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21381/21381-0012
# 21381-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21381/21381-0013
# 21381-0014 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21381/21381-0014
# 21411-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21411/21411-0001
# 21411-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21411/21411-0002
# 21421-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0001
# 21421-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0002
# 21421-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0003
# 21421-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0004
# 21421-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0005
# 21421-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0006
# 21421-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0007
# 21421-0008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0008
# 21421-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0009
# 21421-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0010
# 21421-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21421/21421-0011
# 21611-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0001
# 21611-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0002
# 21611-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0003
# 21611-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0010
# 21611-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0011
# 21611-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0012
# 21611-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0013
# 21611-0020 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0020
# 21611-0100 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0100
# 21611-0101 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0101
# 21611-0102 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0102
# 21611-0110 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0110
# 21611-0111 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0111
# 21611-0120 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0120
# 21611-0121 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0121
# 21611-0122 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0122
# 21611-0123 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0123
# 21611-0200 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0200
# 21611-0201 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0201
# 21611-0210 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21611/21611-0210
# 21711-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21711/21711-0001
# 21711-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21711/21711-0002
# 21711-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21711/21711-0003
# 21711-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21711/21711-0011
# 21721-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21721/21721-0001
# 21721-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21721/21721-0002
# 21721-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21721/21721-0003
# 21811-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21811/21811-0001
# 21811-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21811/21811-0004
# 21811-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21811/21811-0009
# 21811-0020 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21811/21811-0020
# 21811-0023 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21811/21811-0023
# 21821-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21821/21821-0001
# 21821-0100 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/21821/21821-0100
# 22111-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22111/22111-0001
# 22111-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22111/22111-0002
# 22111-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22111/22111-0004
# 22111-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22111/22111-0010
# 22111-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22111/22111-0011
# 22111-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22111/22111-0013
# 22111-0020 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22111/22111-0020
# 22111-0021 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22111/22111-0021
# 22121-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22121/22121-0001
# 22121-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22121/22121-0002
# 22121-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22121/22121-0003
# 22121-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22121/22121-0010
# 22121-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22121/22121-0011
# 22121-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22121/22121-0012
# 22125-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22125/22125-0001
# 22125-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22125/22125-0002
# 22131-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22131/22131-0001
# 22131-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22131/22131-0002
# 22131-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22131/22131-0003
# 22131-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22131/22131-0004
# 22131-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22131/22131-0005
# 22131-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22131/22131-0006
# 22131-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22131/22131-0010
# 22131-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22131/22131-0011
# 22131-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22131/22131-0012
# 22131-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22131/22131-0013
# 22151-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0001
# 22151-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0002
# 22151-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0003
# 22151-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0004
# 22151-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0005
# 22151-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0006
# 22151-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0007
# 22151-0008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0008
# 22151-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0009
# 22151-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0010
# 22151-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0011
# 22151-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0012
# 22151-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0013
# 22151-0014 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0014
# 22151-0015 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0015
# 22151-0016 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0016
# 22151-0017 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0017
# 22151-0018 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0018
# 22151-0020 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0020
# 22151-0021 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0021
# 22151-0022 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0022
# 22151-0023 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0023
# 22151-0024 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0024
# 22151-0025 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22151/22151-0025
# 22211-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22211/22211-0001
# 22211-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22211/22211-0002
# 22211-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22211/22211-0003
# 22211-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22211/22211-0004
# 22211-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22211/22211-0005
# 22211-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22211/22211-0010
# 22211-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22211/22211-0011
# 22211-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22211/22211-0012
# 22211-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22211/22211-0013
# 22211-0014 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22211/22211-0014
# 22221-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22221/22221-0001
# 22221-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22221/22221-0002
# 22221-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22221/22221-0003
# 22221-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22221/22221-0004
# 22221-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22221/22221-0005
# 22221-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22221/22221-0006
# 22221-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22221/22221-0010
# 22221-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22221/22221-0011
# 22231-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22231/22231-0001
# 22231-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22231/22231-0002
# 22231-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22231/22231-0010
# 22231-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22231/22231-0011
# 22311-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22311/22311-0001
# 22311-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22311/22311-0002
# 22311-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22311/22311-0003
# 22311-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22311/22311-0004
# 22311-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22311/22311-0010
# 22311-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22311/22311-0011
# 22311-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22311/22311-0012
# 22311-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22311/22311-0013
# 22411-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22411/22411-0001
# 22411-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22411/22411-0002
# 22411-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22411/22411-0003
# 22411-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22411/22411-0004
# 22411-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22411/22411-0005
# 22411-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22411/22411-0006
# 22412-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22412/22412-0001
# 22412-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22412/22412-0002
# 22412-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22412/22412-0003
# 22412-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22412/22412-0004
# 22412-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22412/22412-0005
# 22412-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22412/22412-0006
# 22412-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22412/22412-0007
# 22421-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22421/22421-0001
# 22421-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22421/22421-0002
# 22421-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22421/22421-0003
# 22518-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22518/22518-0001
# 22518-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22518/22518-0002
# 22521-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22521/22521-0001
# 22521-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22521/22521-0002
# 22521-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22521/22521-0003
# 22521-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22521/22521-0010
# 22521-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22521/22521-0011
# 22522-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22522/22522-0001
# 22522-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22522/22522-0002
# 22522-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22522/22522-0003
# 22522-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22522/22522-0004
# 22522-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22522/22522-0010
# 22522-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22522/22522-0011
# 22522-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22522/22522-0012
# 22522-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22522/22522-0013
# 22523-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0001
# 22523-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0002
# 22523-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0003
# 22523-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0004
# 22523-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0005
# 22523-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0006
# 22523-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0007
# 22523-0008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0008
# 22523-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0009
# 22523-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0010
# 22523-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0011
# 22523-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0012
# 22523-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22523/22523-0013
# 22541-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22541/22541-0001
# 22542-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22542/22542-0001
# 22542-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22542/22542-0002
# 22543-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22543/22543-0001
# 22543-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22543/22543-0002
# 22543-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22543/22543-0003
# 22543-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22543/22543-0004
# 22543-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22543/22543-0005
# 22543-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22543/22543-0006
# 22543-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22543/22543-0007
# 22543-0008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22543/22543-0008
# 22543-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22543/22543-0009
# 22543-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22543/22543-0010
# 22551-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22551/22551-0001
# 22551-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22551/22551-0002
# 22611-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22611/22611-0001
# 22611-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22611/22611-0002
# 22621-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22621/22621-0001
# 22621-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22621/22621-0002
# 22631-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22631/22631-0001
# 22631-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22631/22631-0002
# 22711-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22711/22711-0001
# 22711-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22711/22711-0002
# 22731-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22731/22731-0001
# 22731-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22731/22731-0002
# 22911-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22911/22911-0001
# 22911-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22911/22911-0002
# 22922-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0001
# 22922-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0002
# 22922-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0003
# 22922-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0004
# 22922-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0005
# 22922-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0006
# 22922-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0007
# 22922-0008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0008
# 22922-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0009
# 22922-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0010
# 22922-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0011
# 22922-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0012
# 22922-0020 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0020
# 22922-0021 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0021
# 22922-0022 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0022
# 22922-0023 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0023
# 22922-0024 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0024
# 22922-0025 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0025
# 22922-0026 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0026
# 22922-0027 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0027
# 22922-0028 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0028
# 22922-0029 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0029
# 22922-0030 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0030
# 22922-0031 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0031
# 22922-0101 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0101
# 22922-0102 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0102
# 22922-0103 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0103
# 22922-0104 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0104
# 22922-0105 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0105
# 22922-0106 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0106
# 22922-0107 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0107
# 22922-0108 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0108
# 22922-0109 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0109
# 22922-0110 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0110
# 22922-0111 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0111
# 22922-0112 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0112
# 22922-0113 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0113
# 22922-0114 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0114
# 22922-0115 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0115
# 22922-0116 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0116
# 22922-0117 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0117
# 22922-0118 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0118
# 22922-0119 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0119
# 22922-0120 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0120
# 22922-0121 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0121
# 22922-0122 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0122
# 22922-0123 single positional indexer is out-of-bounds
# 22922-0124 single positional indexer is out-of-bounds
# 22922-0125 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22922/22922-0125
# 22923-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22923/22923-0001
# 22923-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/22923/22923-0003
# 23111-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/23111/23111-0001
# 23111-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/23111/23111-0002
# 23112-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/23112/23112-0001
# ...
# 63121-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/63121/63121-0005
# 63211-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/63211/63211-0001
# 63211-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/63211/63211-0003
# 63211-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/63211/63211-0005
# 63211-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/63211/63211-0007
# 63411-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/63411/63411-0005
# 63411-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/63411/63411-0006
# 71141-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71141/71141-0001
# 71141-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71141/71141-0002
# 71141-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71141/71141-0003
# 71141-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71141/71141-0004
# 71141-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71141/71141-0005
# 71141-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71141/71141-0006
# 71211-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71211/71211-0001
# 71211-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71211/71211-0002
# 71211-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71211/71211-0003
# 71211-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71211/71211-0004
# 71211-0007 single positional indexer is out-of-bounds
# 71231-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71231/71231-0001
# 71231-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71231/71231-0002
# 71231-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71231/71231-0003
# 71231-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71231/71231-0004
# 71321-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71321/71321-0001
# 71321-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71321/71321-0002
# 71321-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71321/71321-0003
# 71321-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71321/71321-0004
# 71321-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71321/71321-0005
# 71321-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71321/71321-0006
# 71321-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71321/71321-0007
# 71411-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71411/71411-0001
# 71411-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71411/71411-0002
# 71411-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/71411/71411-0003
# 73111-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73111/73111-0001
# 73111-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73111/73111-0002
# 73121-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73121/73121-0001
# 73121-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73121/73121-0002
# 73121-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73121/73121-0003
# 73211-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73211/73211-0001
# 73211-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73211/73211-0002
# 73311-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73311/73311-0001
# 73321-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73321/73321-0001
# 73411-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73411/73411-0001
# 73421-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73421/73421-0001
# 73421-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73421/73421-0002
# 73423-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73423/73423-0001
# 73431-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73431/73431-0001
# 73432-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73432/73432-0001
# 73441-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73441/73441-0001
# 73511-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73511/73511-0001
# 73991-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/73991/73991-0001
# 74111-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/74111/74111-0001
# 74111-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/74111/74111-0002
# 74211-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/74211/74211-0001
# 74211-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/74211/74211-0003
# 74211-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/74211/74211-0010
# 74211-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/74211/74211-0012
# 81000-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0001
# 81000-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0002
# 81000-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0003
# 81000-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0004
# 81000-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0005
# 81000-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0006
# 81000-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0007
# 81000-0008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0008
# 81000-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0009
# 81000-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0010
# 81000-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0011
# 81000-0012 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0012
# 81000-0013 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0013
# 81000-0014 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0014
# 81000-0016 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0016
# 81000-0017 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0017
# 81000-0018 single positional indexer is out-of-bounds
# 81000-0019 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0019
# 81000-0020 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0020
# 81000-0021 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0021
# 81000-0022 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0022
# 81000-0023 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0023
# 81000-0024 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0024
# 81000-0025 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0025
# 81000-0026 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0026
# 81000-0027 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0027
# 81000-0028 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0028
# 81000-0029 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0029
# 81000-0030 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0030
# 81000-0031 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0031
# 81000-0032 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0032
# 81000-0033 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0033
# 81000-0034 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0034
# 81000-0050 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0050
# 81000-0101 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0101
# 81000-0102 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0102
# 81000-0103 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0103
# 81000-0104 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0104
# 81000-0105 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0105
# 81000-0106 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0106
# 81000-0107 single positional indexer is out-of-bounds
# 81000-0108 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0108
# 81000-0109 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0109
# 81000-0110 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0110
# 81000-0111 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0111
# 81000-0112 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0112
# 81000-0113 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0113
# 81000-0114 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0114
# 81000-0115 single positional indexer is out-of-bounds
# 81000-0116 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0116
# 81000-0117 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0117
# 81000-0118 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0118
# 81000-0119 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0119
# 81000-0120 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0120
# 81000-0121 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0121
# 81000-0122 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0122
# 81000-0123 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0123
# 81000-0124 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0124
# 81000-0125 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0125
# 81000-0126 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0126
# 81000-0127 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0127
# 81000-0128 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0128
# 81000-0129 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0129
# 81000-0130 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0130
# 81000-0131 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0131
# 81000-0132 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0132
# 81000-0133 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0133
# 81000-0134 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0134
# 81000-0135 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0135
# 81000-0136 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0136
# 81000-0137 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0137
# 81000-0138 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0138
# 81000-0139 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0139
# 81000-0140 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/81000/81000-0140
# 82111-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/82111/82111-0001
# 85111-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/85111/85111-0001
# 85111-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/85111/85111-0002
# 85111-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/85111/85111-0003
# 85131-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/85131/85131-0001
# 85131-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/85131/85131-0002
# 85411-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/85411/85411-0001
# 85411-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/85411/85411-0002
# 85411-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/85411/85411-0003
# 85421-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/85421/85421-0001
# 85421-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/85421/85421-0002
# 91111-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/91111/91111-0001
# 91111-0002 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/91111/91111-0002
# 91211-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/91211/91211-0001
# 91311-0001 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/91311/91311-0001
# 99911-0001 single positional indexer is out-of-bounds
# 99911-0002 single positional indexer is out-of-bounds
# 99911-0003 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/99911/99911-0003
# 99911-0004 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/99911/99911-0004
# 99911-0005 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/99911/99911-0005
# 99911-0006 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/99911/99911-0006
# 99911-0007 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/99911/99911-0007
# 99911-0008 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/99911/99911-0008
# 99911-0009 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/99911/99911-0009
# 99911-0010 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/99911/99911-0010
# 99911-0011 - /Users/muditsharma/Documents/Knoema/Federal Statistical Office (Destatis)/99911/99911-0011
# 99911-0012 single positional indexer is out-of-bounds
