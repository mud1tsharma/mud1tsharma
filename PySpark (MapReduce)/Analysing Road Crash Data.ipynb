# %% [markdown]
# # 1.1 - Data Preparation & Loading

# %%
# Import the necessary libraries

from pyspark.sql.functions import col
from pyspark.sql.functions import concat
from pyspark.sql.functions import lit
from pyspark.sql import Row
import pandas as pd
import ast

# %% [markdown]
# ## 1.1.1

# %%
# Import SparkConf class into program
from pyspark import SparkConf
from pyspark import SparkContext # Spark
from pyspark.sql import SparkSession # Spark SQL

# Setup configuration parameters for Spark
master = "local[*]"
app_name = "msha0060 Assignment 1"
spark_conf = SparkConf().setMaster(master).setAppName(app_name)

spark = SparkSession.builder.config(conf=spark_conf).getOrCreate()
sc = spark.sparkContext
sc.setLogLevel('ERROR')

# %% [markdown]
# ## 1.1.2

# %%
# Import 5 CSV Files
Units1 = sc.textFile("2015_DATA_SA_Units.csv")
Units2 = sc.textFile("2016_DATA_SA_Units.csv")
Units3 = sc.textFile("2017_DATA_SA_Units.csv")
Units4 = sc.textFile("2018_DATA_SA_Units.csv")
Units5 = sc.textFile("2019_DATA_SA_Units.csv")

# Sequentially merge Unit2, Unit3, Unit4, and then Unit5 into Unit1
UnitsA = Units1.union(Units2)
UnitsB = UnitsA.union(Units3)
UnitsC = UnitsB.union(Units4)
Units = UnitsC.union(Units5)

# %% [markdown]
# ## 1.1.3

# %%
# Import 5 CSV Files
Crash1 = sc.textFile("2015_DATA_SA_Crash.csv")
Crash2 = sc.textFile("2016_DATA_SA_Crash.csv")
Crash3 = sc.textFile("2017_DATA_SA_Crash.csv")
Crash4 = sc.textFile("2018_DATA_SA_Crash.csv")
Crash5 = sc.textFile("2019_DATA_SA_Crash.csv")

# Sequentially merge Crash1, Crash3, Crash4, and then Crash5 into Crash1
CrashA = Crash1.union(Crash2)
CrashB = CrashA.union(Crash3)
CrashC = CrashB.union(Crash4)
Crash = CrashC.union(Crash5)

# %% [markdown]
# ## 1.1.4

# %%
# Identify the header row
header = Units.first()

# Filter Units to include every row that is not the header row
Units = Units.filter(lambda x: x != header)

# Split every line on a comma, as these are CSV files
Units = Units.map(lambda x: x.split(','))

# %%
# Identify the header row
header = Crash.first()

# Filter Units to include every row that is not the header row
Crash = Crash.filter(lambda x: x != header)

# Split every line on a comma, as these are CSV files
Crash = Crash.map(lambda x: (x.split(',')))

# %%
# Count the number of rows in the Units RDD
print ('There are', Units.count(),'rows in the Units RDD excluding the header:\n')
Units.take(10)
# Out:
# There are 153859 rows in the Units RDD excluding the header:
# [['"REPORT_ID"',
#   '"Unit No"',
#   '"No Of Cas"',
#   '"Veh Reg State"',
#   '"Unit Type"',
#   '"Veh Year"',
#   '"Direction Of Travel"',
#   '"Sex"',
#   '"Age"',
#   '"Lic State"',
#   '"Licence Class"',
#   '"Licence Type"',
#   '"Towing"',
#   '"Unit Movement"',
#   '"Number Occupants"',
#   '"Postcode"',
#   '"Rollover"',
#   '"Fire"'],
#  ['"2015-1-21/08/2019"',
#   '"01"',
#   '0',
#   '"SA"',
#   '"RIGID TRUCK LGE GE 4.5T"',
#   '"1999"',
#   '"North East"',
#   '"Male"',
#   '"052"',
#   '"SA"',
#   '"HRR "',
#   '"Full"',
#   '"Not Towing"',
#   '"Swerving"',
#   '"001"',
#   '"5109"',
#   '',
#   ''],
#  ['"2015-1-21/08/2019"',
#   '"02"',
#   '1',
#   '"SA"',
#   '"Motor Cars - Sedan"',
#   '"2009"',
#   '"North East"',
#   '"Female"',
#   '"057"',
#   '"SA"',
#   '"C "',
#   '"Full"',
#   '"Not Towing"',
#   '"Straight Ahead"',
#   '"002"',
#   '"5125"',
#   '',
#   ''],
#  ['"2015-2-21/08/2019"',
#   '"01"',
#   '0',
#   '"SA"',
#   '"Motor Cars - Sedan"',
#   '"2009"',
#   '"South East"',
#   '"Male"',
#   '"020"',
#   '"SA"',
#   '"MR"',
#   '"Provisional 1 "',
#   '"Not Towing"',
#   '"Straight Ahead"',
#   '"001"',
#   '"5110"',
#   '',
#   ''],
#  ['"2015-2-21/08/2019"',
#   '"02"',
#   '1',
#   '"SA"',
#   '"Motor Cars - Sedan"',
#   '"1994"',
#   '"South East"',
#   '"Female"',
#   '"021"',
#   '"SA"',
#   '"C "',
#   '"Full"',
#   '"Not Towing"',
#   '"Stopped on Carriageway"',
#   '"001"',
#   '"5096"',
#   '',
#   ''],
#  ['"2015-3-21/08/2019"',
#   '"01"',
#   '0',
#   '"SA"',
#   '"Motor Cars - Sedan"',
#   '"2008"',
#   '"North East"',
#   '"Male"',
#   '"023"',
#   '"SA"',
#   '"C "',
#   '"Full"',
#   '"Not Towing"',
#   '"Straight Ahead"',
#   '"001"',
#   '"5034"',
#   '',
#   ''],
#  ['"2015-3-21/08/2019"',
#   '"02"',
#   '1',
#   '"SA"',
#   '"Motor Cars - Sedan"',
#   '"2007"',
#   '"North East"',
#   '"Female"',
#   '"025"',
#   '"SA"',
#   '"C "',
#   '"Full"',
#   '"Not Towing"',
#   '"Stopped on Carriageway"',
#   '"001"',
#   '"5015"',
#   '',
#   ''],
#  ['"2015-4-21/08/2019"',
#   '"01"',
#   '0',
#   '"SA"',
#   '"Station Wagon"',
#   '"1992"',
#   '"West"',
#   '"Male"',
#   '"059"',
#   '"SA"',
#   '"C R "',
#   '"Full"',
#   '"Not Towing"',
#   '"Straight Ahead"',
#   '"001"',
#   '"5043"',
#   '',
#   ''],
#  ['"2015-4-21/08/2019"',
#   '"02"',
#   '0',
#   '"SA"',
#   '"Motor Cars - Sedan"',
#   '"2009"',
#   '"West"',
#   '"Male"',
#   '"040"',
#   '"SA"',
#   '"C "',
#   '"Full"',
#   '"Not Towing"',
#   '"Stopped on Carriageway"',
#   '"003"',
#   '"5044"',
#   '',
#   ''],
#  ['"2015-4-21/08/2019"',
#   '"03"',
#   '0',
#   '"SA"',
#   '"Motor Cars - Sedan"',
#   '"2006"',
#   '"West"',
#   '"Male"',
#   '"038"',
#   '"SA"',
#   '"C R "',
#   '"Full"',
#   '"Not Towing"',
#   '"Stopped on Carriageway"',
#   '"001"',
#   '"5022"',
#   '',
#   '']]

# %%
# Count the number of rows in the Crash RDD
print ('There are', Crash.count(),'rows in the Crash RDD excluding the header:\n')
Crash.take(10)
# Out:
# There are 72006 rows in the Crash RDD excluding the header:
# [['"2015-1-21/08/2019"',
#   '"2 Metropolitan"',
#   '"ELIZABETH VALE"',
#   '"5112"',
#   '"CITY OF PLAYFORD."',
#   '2',
#   '1',
#   '0',
#   '0',
#   '1',
#   '2015',
#   '"January"',
#   '"Wednesday"',
#   '"01:00 pm"',
#   '"060"',
#   '"T-Junction"',
#   '"Straight road"',
#   '"Level"',
#   '"Not Applicable"',
#   '"Sealed"',
#   '"Dry"',
#   '"Not Raining"',
#   '"Daylight"',
#   '"Side Swipe"',
#   '"01"',
#   '"Driver Rider"',
#   '"2: MI"',
#   '"No Control"',
#   '""',
#   '""',
#   '1335254.54',
#   '1690056.88',
#   '"13352551690057"'],
#  ['"2015-2-21/08/2019"',
#   '"2 Metropolitan"',
#   '"SALISBURY"',
#   '"5108"',
#   '"CITY OF SALISBURY"',
#   '2',
#   '1',
#   '0',
#   '0',
#   '1',
#   '2015',
#   '"February"',
#   '"Tuesday"',
#   '"03:38 pm"',
#   '"060"',
#   '"Cross Road"',
#   '"Straight road"',
#   '"Level"',
#   '"Not Applicable"',
#   '"Sealed"',
#   '"Dry"',
#   '"Not Raining"',
#   '"Daylight"',
#   '"Rear End"',
#   '"01"',
#   '"Driver Rider"',
#   '"2: MI"',
#   '"Traffic Signals"',
#   '""',
#   '""',
#   '1333389.6',
#   '1688248.34',
#   '"13333901688248"'],
#  ['"2015-3-21/08/2019"',
#   '"2 Metropolitan"',
#   '"ST MARYS"',
#   '"5042"',
#   '"CC MITCHAM.                   "',
#   '2',
#   '1',
#   '0',
#   '0',
#   '1',
#   '2015',
#   '"March"',
#   '"Tuesday"',
#   '"01:15 pm"',
#   '"070"',
#   '"Cross Road"',
#   '"Straight road"',
#   '"Level"',
#   '"Not Applicable"',
#   '"Sealed"',
#   '"Dry"',
#   '"Not Raining"',
#   '"Daylight"',
#   '"Rear End"',
#   '"01"',
#   '"Driver Rider"',
#   '"2: MI"',
#   '"Traffic Signals"',
#   '""',
#   '""',
#   '1326004.51',
#   '1661277.67',
#   '"13260051661278"'],
#  ['"2015-4-21/08/2019"',
#   '"2 Metropolitan"',
#   '"MITCHELL PARK"',
#   '"5043"',
#   '"CC MARION.                    "',
#   '3',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2015',
#   '"January"',
#   '"Friday"',
#   '"11:15 am"',
#   '"060"',
#   '"Divided Road"',
#   '"Straight road"',
#   '"Level"',
#   '"Not Applicable"',
#   '"Sealed"',
#   '"Dry"',
#   '"Not Raining"',
#   '"Daylight"',
#   '"Rear End"',
#   '"01"',
#   '"Driver Rider"',
#   '"1: PDO"',
#   '"No Control"',
#   '""',
#   '""',
#   '1324707.6',
#   '1660681.57',
#   '"13247081660682"'],
#  ['"2015-5-21/08/2019"',
#   '"2 Metropolitan"',
#   '"NORTH BRIGHTON"',
#   '"5048"',
#   '"CITY OF HOLDFAST BAY"',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2015',
#   '"January"',
#   '"Sunday"',
#   '"06:05 pm"',
#   '"050"',
#   '"Cross Road"',
#   '"Straight road"',
#   '"Level"',
#   '"Not Applicable"',
#   '"Sealed"',
#   '"Dry"',
#   '"Not Raining"',
#   '"Daylight"',
#   '"Rear End"',
#   '"01"',
#   '"Driver Rider"',
#   '"1: PDO"',
#   '"Stop Sign"',
#   '""',
#   '""',
#   '1320769.68',
#   '1661801.51',
#   '"13207701661802"'],
#  ['"2015-6-21/08/2019"',
#   '"2 Metropolitan"',
#   '"SALISBURY DOWNS"',
#   '"5108"',
#   '"CITY OF SALISBURY"',
#   '2',
#   '1',
#   '0',
#   '0',
#   '1',
#   '2015',
#   '"January"',
#   '"Monday"',
#   '"03:40 pm"',
#   '"060"',
#   '"Cross Road"',
#   '"Straight road"',
#   '"Level"',
#   '"Not Applicable"',
#   '"Sealed"',
#   '"Dry"',
#   '"Not Raining"',
#   '"Daylight"',
#   '"Rear End"',
#   '"01"',
#   '"Driver Rider"',
#   '"2: MI"',
#   '"Traffic Signals"',
#   '""',
#   '""',
#   '1331438.94',
#   '1686827.09',
#   '"13314391686827"'],
#  ['"2015-7-21/08/2019"',
#   '"2 Metropolitan"',
#   '"EDWARDSTOWN"',
#   '"5039"',
#   '"CC MARION.                    "',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2015',
#   '"January"',
#   '"Monday"',
#   '"06:15 pm"',
#   '"050"',
#   '"Cross Road"',
#   '"Straight road"',
#   '"Level"',
#   '"Not Applicable"',
#   '"Sealed"',
#   '"Dry"',
#   '"Not Raining"',
#   '"Daylight"',
#   '"Right Angle"',
#   '"02"',
#   '"Driver Rider"',
#   '"1: PDO"',
#   '"Stop Sign"',
#   '""',
#   '""',
#   '1325689.36',
#   '1665269.62',
#   '"13256891665270"'],
#  ['"2015-8-21/08/2019"',
#   '"1 City"',
#   '"NORTH ADELAIDE"',
#   '"5006"',
#   '"CITY OF ADELAIDE"',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2015',
#   '"January"',
#   '"Tuesday"',
#   '"12:30 pm"',
#   '"050"',
#   '"Not Divided"',
#   '"Straight road"',
#   '"Level"',
#   '"Not Applicable"',
#   '"Sealed"',
#   '"Dry"',
#   '"Not Raining"',
#   '"Daylight"',
#   '"Rear End"',
#   '"01"',
#   '"Driver Rider"',
#   '"1: PDO"',
#   '"No Control"',
#   '""',
#   '""',
#   '1328296.1',
#   '1671670.41',
#   '"13282961671670"'],
#  ['"2015-9-21/08/2019"',
#   '"2 Metropolitan"',
#   '"PLYMPTON"',
#   '"5038"',
#   '"CITY OF WEST TORRENS"',
#   '2',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2015',
#   '"January"',
#   '"Monday"',
#   '"07:30 pm"',
#   '"060"',
#   '"Divided Road"',
#   '"Straight road"',
#   '"Level"',
#   '"Not Applicable"',
#   '"Sealed"',
#   '"Dry"',
#   '"Not Raining"',
#   '"Daylight"',
#   '"Rear End"',
#   '"02"',
#   '"Driver Rider"',
#   '"1: PDO"',
#   '"No Control"',
#   '""',
#   '""',
#   '1324317.73',
#   '1666625.75',
#   '"13243181666626"'],
#  ['"2015-10-21/08/2019"',
#   '"2 Metropolitan"',
#   '"NORWOOD"',
#   '"5067"',
#   '"CC OF NORWOOD',
#   'PAYNEHAM & ST PETERS"',
#   '2',
#   '1',
#   '0',
#   '0',
#   '1',
#   '2015',
#   '"January"',
#   '"Thursday"',
#   '"02:35 pm"',
#   '"050"',
#   '"Cross Road"',
#   '"Straight road"',
#   '"Level"',
#   '"Not Applicable"',
#   '"Sealed"',
#   '"Dry"',
#   '"Not Raining"',
#   '"Daylight"',
#   '"Rear End"',
#   '"02"',
#   '"Driver Rider"',
#   '"2: MI"',
#   '"Traffic Signals"',
#   '""',
#   '""',
#   '1331854.38',
#   '1671072.44',
#   '"13318541671072"']]

# %% [markdown]
# # 1.2 - Data Partitioning in RDD
# ## 1.2.1

# %%
# Find the number of partitions in each RDD
print ('There are', Units.getNumPartitions(),'partitions in the Units RDD\n')
print ('There are', Crash.getNumPartitions(),'partitions in the Crash RDD\n')
# Out:
# There are 10 partitions in the Units RDD
#
# There are 10 partitions in the Crash RDD

# %% [markdown]
# #### By default, Spark performs Random-Equal Partitioning, wherein each processor receives an equal share (or sub-table) of the original table.

# %% [markdown]
# ## 1.2.2 - A

# %%
# Transofrm Units into a Key-Value RDD (Units1), with REPORT_ID as the Key and all other columns as the Value

Units1 = Units\
.map(lambda x: (x[9], x[0:9]+x[10:]))

# %%
# Verifying that Units is now a Key-Value RDD

Units1.take(1)
# Out:
# [('"SA"',
#   ['"2015-1-21/08/2019"',
#    '"01"',
#    '0',
#    '"SA"',
#    '"RIGID TRUCK LGE GE 4.5T"',
#    '"1999"',
#    '"North East"',
#    '"Male"',
#    '"052"',
#    '"HRR "',
#    '"Full"',
#    '"Not Towing"',
#    '"Swerving"',
#    '"001"',
#    '"5109"',
#    '',
#    ''])]

# %% [markdown]
# ## 1.2.2 - B

# %%
# Define a range function based on the value of the key

def range_function(key):
    if key == '"SA"':
        return 0
    else:
        return 1

# %%
# Apply the range function to Units1

Units2 = Units1.partitionBy(2, range_function)
UnitsPartition=Units2.glom().collect()

# %%
# Verify the partitioning by printing out the first 5 keys in each partition

print('The key for the first row in Parition 0 (corresponding to SA) is: ',\
      [x[0].strip('""') for x in UnitsPartition[0]][:5])

# Filter out null and unknown keys for the sake of this verification
print('The key for the fifth row in Parition 1 (NOT corresponding to SA) is: ',\
      [x[0].strip('""') for x in UnitsPartition[1] if (x[0] != '' and x[0] != '"UNKNOWN"')][:5])
# Out:
# The key for the first row in Parition 0 (corresponding to SA) is:  ['SA', 'SA', 'SA', 'SA', 'SA']
# The key for the fifth row in Parition 1 (NOT corresponding to SA) is:  ['QLD', 'O/S', 'VIC', 'QLD', 'NT']

# %% [markdown]
# ## 1.2.2 - C

# %%
print ("The first partition, containing records specific to SA contains",len(UnitsPartition[0]),'records')
print ("The first partition, containing records specific to other areas contains",len(UnitsPartition[1]),'records')
print ("The 2 partitions together contain",len(UnitsPartition[1])+len(UnitsPartition[0]),'records')
# Out:
# The first partition, containing records specific to SA contains 109684 records
# The first partition, containing records specific to other areas contains 44170 records
# The 2 partitions together contain 153854 records

# %% [markdown]
# #### We can see that the Units corresponding to SA comprise ~71% of the total data, and that all other regions only account for ~29% of the total data. This represents a large skew towards records dealing with 'SA', as the 'Other' category includes several regions.

# %% [markdown]
# # 1.3 - Query Analysis
# ## 1.3.1

# %%
# Define entities that are not drivers
nonDrivers = ['"Guard Rail"','"Other Fixed Obstruction"','"Other Inanimate Object"',\
              '"Pedestrian on Road"','"Stobie Pole"','"Traffic Signal Pole"',\
              '"Tree"','"Utility"']

# Define lists to help filter out invalid values in the following cells
nonAge = ['""'," ","",''""'','"XXX"','"XXXX"']

# %%
# Filter out Male drivers, and calculate the mean of their ages
# Here, we use the above defined lists to filter out wrong or inappropriate values for this query
# We also filter for ages < 150, because of the presence of an incorrectly entered record listing an age > 500
UnitsMale = Units\
.filter(lambda x: x[7]=='"Male"')\
.filter(lambda x: x[4] not in nonDrivers)\
.filter(lambda x: x[8] not in nonAge)\
.map(lambda x: x[8].strip('""'))\
.map(lambda x: float(x))\
.filter(lambda x: int(x)<150).mean()

# %%
# Filter out female drivers and calculate the mean of their ages
UnitsFemale = Units\
.filter(lambda x: x[7]=='"Female"')\
.filter(lambda x: x[4] not in nonDrivers)\
.filter(lambda x: x[8] not in nonAge)\
.map(lambda x: x[8].strip('""'))\
.map(lambda x: float(x))\
.filter(lambda x: int(x)<150).mean()

# %%
print('The average age of male drivers is', round(UnitsMale,2))
print('The average age of female drivers is', round(UnitsFemale,2))
# Out:
# The average age of male drivers is 41.14
# The average age of female drivers is 40.41

# %% [markdown]
# ## 1.3.2

# %%
nonAge = ['""'," ","",''""'','"XXX"','"XXXX"']

# Filter incorrectly entered 'Veh Year' values
UnitsVehYear=Units\
.filter(lambda x: x[5] not in nonAge)\
.map(lambda x: x[3:6])

# %%
# Find the maximum and minimum values in the 'Veh Year' columns
UnitsMax = [x.strip('""') for x in UnitsVehYear.max(key = lambda x: x[-1])]
UnitsMin = [x.strip('""') for x in UnitsVehYear.min(key = lambda x: x[-1])]

# %%
print('Information for the newest vehicle involved in an accident: ',UnitsMax)
print('Information for the oldest vehicle involved in an accident: ',UnitsMin)
# Out:
# Information for the newest vehicle involved in an accident:  ['SA', 'Station Wagon', '2019']
# Information for the oldest vehicle involved in an accident:  ['VIC', 'Motor Cycle', '1900']

# %% [markdown]
# # 2 - Working with Dataframes
# ## 2.1 - Data Preparation & Loading
# ## 2.1.1

# %%
# Import 5 CSV Files
Units1 = spark.read.csv("2015_DATA_SA_Units.csv")
Units2 = spark.read.csv("2016_DATA_SA_Units.csv")
Units3 = spark.read.csv("2017_DATA_SA_Units.csv")
Units4 = spark.read.csv("2018_DATA_SA_Units.csv")
Units5 = spark.read.csv("2019_DATA_SA_Units.csv")

# Sequentially merge Unit2, Unit3, Unit4, and then Unit5 into Unit1
UnitsA = Units1.union(Units2)
UnitsB = UnitsA.union(Units3)
UnitsC = UnitsB.union(Units4)
Units = UnitsC.union(Units5)

# Because of the merges, the header would have been repeated 4 times so we drop duplicates
header = Units.first()
Units = Units.filter(col("_c0")!="REPORT_ID")

# Rename the columns based on the header row
for i in range(0,len(Units.columns)):
    Units = Units.withColumnRenamed(Units.columns[i],header[i])

# %%
# Import 5 CSV Files
Crash1 = spark.read.csv("2015_DATA_SA_Crash.csv")
Crash2 = spark.read.csv("2016_DATA_SA_Crash.csv")
Crash3 = spark.read.csv("2017_DATA_SA_Crash.csv")
Crash4 = spark.read.csv("2018_DATA_SA_Crash.csv")
Crash5 = spark.read.csv("2019_DATA_SA_Crash.csv")

# Sequentially merge Crash1, Crash3, Crash4, and then Crash5 into Crash1
CrashA = Crash1.union(Crash2)
CrashB = CrashA.union(Crash3)
CrashC = CrashB.union(Crash4)
Crash = CrashC.union(Crash5)

# Because of the merges, the header would have been repeated 4 times so we drop duplicates
header = Crash.first()
Crash = Crash.filter(col("_c0")!="REPORT_ID")

# Rename the columns based on the header row
for i in range(0,len(Crash.columns)):
    Crash = Crash.withColumnRenamed(Crash.columns[i],header[i])

# %% [markdown]
# ## 2.1.2

# %%
Units.printSchema()    
Crash.printSchema()
# Out:
# root
#  |-- REPORT_ID: string (nullable = true)
#  |-- Unit No: string (nullable = true)
#  |-- No Of Cas: string (nullable = true)
#  |-- Veh Reg State: string (nullable = true)
#  |-- Unit Type: string (nullable = true)
#  |-- Veh Year: string (nullable = true)
#  |-- Direction Of Travel: string (nullable = true)
#  |-- Sex: string (nullable = true)
#  |-- Age: string (nullable = true)
#  |-- Lic State: string (nullable = true)
#  |-- Licence Class: string (nullable = true)
#  |-- Licence Type: string (nullable = true)
#  |-- Towing: string (nullable = true)
#  |-- Unit Movement: string (nullable = true)
#  |-- Number Occupants: string (nullable = true)
#  |-- Postcode: string (nullable = true)
#  |-- Rollover: string (nullable = true)
#  |-- Fire: string (nullable = true)
#
# root
#  |-- REPORT_ID: string (nullable = true)
#  |-- Stats Area: string (nullable = true)
#  |-- Suburb: string (nullable = true)
#  |-- Postcode: string (nullable = true)
#  |-- LGA Name: string (nullable = true)
#  |-- Total Units: string (nullable = true)
#  |-- Total Cas: string (nullable = true)
#  |-- Total Fats: string (nullable = true)
#  |-- Total SI: string (nullable = true)
#  |-- Total MI: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- Month: string (nullable = true)
#  |-- Day: string (nullable = true)
#  |-- Time: string (nullable = true)
#  |-- Area Speed: string (nullable = true)
#  |-- Position Type: string (nullable = true)
#  |-- Horizontal Align: string (nullable = true)
#  |-- Vertical Align: string (nullable = true)
#  |-- Other Feat: string (nullable = true)
#  |-- Road Surface: string (nullable = true)
#  |-- Moisture Cond: string (nullable = true)
#  |-- Weather Cond: string (nullable = true)
#  |-- DayNight: string (nullable = true)
#  |-- Crash Type: string (nullable = true)
#  |-- Unit Resp: string (nullable = true)
#  |-- Entity Code: string (nullable = true)
#  |-- CSEF Severity: string (nullable = true)
#  |-- Traffic Ctrls: string (nullable = true)
#  |-- DUI Involved: string (nullable = true)
#  |-- Drugs Involved: string (nullable = true)
#  |-- ACCLOC_X: string (nullable = true)
#  |-- ACCLOC_Y: string (nullable = true)
#  |-- UNIQUE_LOC: string (nullable = true)

# %% [markdown]
# # 2.2 - Query/Analysis
# ## 2.2.1

# %%
# Filter on Adelaide, then Filter on there being >3 casualties, and display relevant columns
Crash221 = Crash\
.filter(col("Suburb")=="ADELAIDE")\
.filter(col("Total Cas")>3)\
.select('REPORT_ID','Suburb','Total Cas','Year','Month','Day')\
.show()
# Out:
# +--------------------+--------+---------+----+--------+--------+
# |           REPORT_ID|  Suburb|Total Cas|Year|   Month|     Day|
# +--------------------+--------+---------+----+--------+--------+
# |2017-1613-15/08/2019|ADELAIDE|        4|2017|February|Saturday|
# |2017-12182-15/08/...|ADELAIDE|        5|2017|December|Saturday|
# | 2018-601-17/01/2020|ADELAIDE|        4|2018| January|  Sunday|
# |2019-10404-8/07/2020|ADELAIDE|        6|2019| October|  Monday|
# +--------------------+--------+---------+----+--------+--------+

# %% [markdown]
# ## 2.2.2

# %%
# Order casualties in descending order, and display relevant columns
Crash222 = Crash\
.orderBy((Crash['Total Cas'])\
.desc())\
.select('REPORT_ID','Total Cas','Suburb','Year','Month','Day')\
.show(10)
# Out:
# +--------------------+---------+---------------+----+--------+---------+
# |           REPORT_ID|Total Cas|         Suburb|Year|   Month|      Day|
# +--------------------+---------+---------------+----+--------+---------+
# |2016-6630-15/08/2019|        9|  KANGAROO FLAT|2016|   April|Wednesday|
# |2016-3035-15/08/2019|        9|        HACKHAM|2016| January| Saturday|
# |2019-11734-8/07/2020|        9|          STURT|2019|November|   Sunday|
# |2016-7073-15/08/2019|        8|       MERRITON|2016|   April|   Sunday|
# |2015-2823-21/08/2019|        8|         HAWKER|2015|   March|   Monday|
# |2016-14407-15/08/...|        8|      STOCKWELL|2016| October|   Sunday|
# |2017-7615-15/08/2019|        7| SOUTH PLYMPTON|2017|    July| Saturday|
# |2015-13713-21/08/...|        7|ELIZABETH GROVE|2015|November|   Friday|
# |2015-12591-21/08/...|        7|        MALLALA|2015| October|   Sunday|
# |2016-8547-15/08/2019|        7|        WINDSOR|2016|     May| Saturday|
# +--------------------+---------+---------------+----+--------+---------+
# only showing top 10 rows

# %% [markdown]
# ## 2.2.3

# %%
# Group Crash by Crash Type, aggregating on Total Casualties
Crash223 = Crash\
.groupBy('Crash Type')\
.agg({'Total Fats': 'sum'})\
.withColumnRenamed('sum(Total Fats)','Fatalities')

# Order the table in descending order of fatalities
Crash223\
.orderBy(Crash223['Fatalities']\
.desc())\
.show()
# Out:
# +--------------------+----------+
# |          Crash Type|Fatalities|
# +--------------------+----------+
# |    Hit Fixed Object|     152.0|
# |             Head On|      86.0|
# |      Hit Pedestrian|      70.0|
# |           Roll Over|      57.0|
# |         Right Angle|      45.0|
# |          Side Swipe|      20.0|
# |          Right Turn|      18.0|
# |            Rear End|      16.0|
# |  Hit Parked Vehicle|       9.0|
# |          Hit Animal|       4.0|
# |  Hit Object on Road|       2.0|
# |               Other|       2.0|
# |Left Road - Out o...|       1.0|
# +--------------------+----------+

# %% [markdown]
# ## 2.2.4

# %%
# Inner Join the filtered DataFrames on REPORT_ID, grouping by Suburb, and aggregating on Total Casualties
Crash224 = Crash\
.join(Units,'REPORT_ID',how = 'inner')\
.groupBy('Suburb')\
.agg({'Total Cas': 'sum'})\
.withColumnRenamed('sum(Total Cas)','Total Casualties')

# Order the table in descending order of casualties
Crash224\
.orderBy(Crash224['Total Casualties']\
.desc())\
.show()
# Out:
# +-----------------+----------------+
# |           Suburb|Total Casualties|
# +-----------------+----------------+
# |         ADELAIDE|          2343.0|
# |         PROSPECT|           791.0|
# |   NORTH ADELAIDE|           708.0|
# |     MAWSON LAKES|           669.0|
# |            STURT|           598.0|
# |   SALISBURY EAST|           557.0|
# |          NORWOOD|           553.0|
# |    MORPHETT VALE|           551.0|
# |     MOUNT BARKER|           542.0|
# |          POORAKA|           481.0|
# |    MOUNT GAMBIER|           472.0|
# |        SALISBURY|           470.0|
# |      GEPPS CROSS|           452.0|
# |       INGLE FARM|           425.0|
# |         PARADISE|           409.0|
# |        WINGFIELD|           405.0|
# |          MODBURY|           403.0|
# |PARAFIELD GARDENS|           391.0|
# |        PARALOWIE|           389.0|
# |          KLEMZIG|           368.0|
# +-----------------+----------------+
# only showing top 20 rows

# %% [markdown]
# # 2.3 - Severity Analysis
# ## 2.3.1

# %%
# Group by by CSEF Severity, and aggregate over count
Crash231 = Crash\
.groupBy('CSEF Severity')\
.agg({'CSEF Severity': 'count'})\
.withColumnRenamed('count(CSEF Severity)','Count')

print ('Fatalities across all Severity Types:')

# Arrange in descending order of count
Crash231\
.orderBy(Crash231['Count']\
.desc())\
.show()
# Out:
# Fatalities across all Severity Types:
# +-------------+-----+
# |CSEF Severity|Count|
# +-------------+-----+
# |       1: PDO|46696|
# |        2: MI|21881|
# |        3: SI| 2978|
# |     4: Fatal|  451|
# +-------------+-----+

# %% [markdown]
# #### PDO (Property Damage Only) seems to be the most common Crash Type

# %% [markdown]
# ## 2.3.2

# %%
# Define 4 DataFrames based on the different combinations in Drugs Involved and DUI Involved

# DUI ONLY
CrashDUI = Crash\
.filter(col('DUI Involved')=='Y')\
.filter(col('Drugs Involved').isNull())

# DRUGS ONLY
CrashDrugs = Crash\
.filter(col('Drugs Involved')=='Y')\
.filter(col('DUI Involved').isNull())

# BOTH DUI AND DRUGS
CrashDUIDrugs = Crash\
.filter(col('DUI Involved')=='Y')\
.filter(col('Drugs Involved')=='Y')

# NEITHER DUI NOR DRUGS
CrashNoDUIDrugs = Crash\
.filter(col('Drugs Involved').isNull())\
.filter(col('DUI Involved').isNull())

# %% [markdown]
# ## 2.3.2 [A - D]

# %%
# Text to describe each of 4 outputted tables
Labels = ['Crash Events for Drugs but NO Alcohol:'\
         ,'Crash Events for Alcohol but NO Drugs:'\
         ,'Crash Events for Alcohol AND Drugs:'\
         ,'Crash Events for NO Alcohol and NO Drugs:']

# Names of the 4 DataFrames generated in the previous cell
Dataframes = [CrashDUI,CrashDrugs,CrashDUIDrugs,CrashNoDUIDrugs]

# Iterate through the 4 DataFrames, performing the same grouping and aggregation functions on each
for dataframe in Dataframes:
    
    Crash232 = dataframe\
    .groupBy('CSEF Severity')\
    .agg({'CSEF Severity': 'count'})

    # Rename columns for readability
    Crash232 = Crash232\
    .withColumnRenamed('count(CSEF Severity)','Count')

    # In each DataFrame, collect the sum total of fatalities to be able to get each Severity's percentage
    Crash232Total = sum(Crash232\
                        .select(['Count'])\
                        .rdd.flatMap(lambda x: x)\
                        .collect())
    
    print (Labels[Dataframes\
                  .index(dataframe)])
    
    # Calculate each condition's percentage based on the total derived above, ordering by raw count of Crash events
    Crash232 = Crash232\
    .withColumn('Percentage',100*Crash232['Count']/Crash232Total)\
    .orderBy(Crash232['Count']\
    .desc())\
    .show()
# Out:
# Crash Events for Drugs but NO Alcohol:
# +-------------+-----+------------------+
# |CSEF Severity|Count|        Percentage|
# +-------------+-----+------------------+
# |       1: PDO| 1149| 55.42691751085383|
# |        2: MI|  648| 31.25904486251809|
# |        3: SI|  224|10.805595754944525|
# |     4: Fatal|   52|2.5084418716835506|
# +-------------+-----+------------------+
#
# Crash Events for Alcohol but NO Drugs:
# +-------------+-----+------------------+
# |CSEF Severity|Count|        Percentage|
# +-------------+-----+------------------+
# |        2: MI|  660| 61.16774791473587|
# |        3: SI|  212|19.647822057460612|
# |       1: PDO|  152|14.087117701575533|
# |     4: Fatal|   55| 5.097312326227989|
# +-------------+-----+------------------+
#
# Crash Events for Alcohol AND Drugs:
# +-------------+-----+------------------+
# |CSEF Severity|Count|        Percentage|
# +-------------+-----+------------------+
# |        2: MI|   89|50.857142857142854|
# |        3: SI|   35|              20.0|
# |     4: Fatal|   27|15.428571428571429|
# |       1: PDO|   24|13.714285714285714|
# +-------------+-----+------------------+
#
# Crash Events for NO Alcohol and NO Drugs:
# +-------------+-----+------------------+
# |CSEF Severity|Count|        Percentage|
# +-------------+-----+------------------+
# |       1: PDO|45371| 66.06240626683557|
# |        2: MI|20484|29.825710916000524|
# |        3: SI| 2507|3.6503152346423215|
# |     4: Fatal|  317|0.4615675825215859|
# +-------------+-----+------------------+

# %% [markdown]
# # 2.4 - RDDs vs DataFrame vs Spark SQL
#
# ## [RDD]

# %%
# Import 5 CSV Files
Units1 = sc.textFile("2015_DATA_SA_Units.csv")
Units2 = sc.textFile("2016_DATA_SA_Units.csv")
Units3 = sc.textFile("2017_DATA_SA_Units.csv")
Units4 = sc.textFile("2018_DATA_SA_Units.csv")
Units5 = sc.textFile("2019_DATA_SA_Units.csv")

# Sequentially merge Unit2, Unit3, Unit4, and then Unit5 into Unit1
UnitsA = Units1.union(Units2)
UnitsB = UnitsA.union(Units3)
UnitsC = UnitsB.union(Units4)
Units = UnitsC.union(Units5)

# Identify the header row
header = Units.first()

# Filter Units to include every row that is not the header row
Units = Units.filter(lambda x: x != header).map(lambda x: (x.split(',')))

# %%
# Import 5 CSV Files
Crash1 = sc.textFile("2015_DATA_SA_Crash.csv")
Crash2 = sc.textFile("2016_DATA_SA_Crash.csv")
Crash3 = sc.textFile("2017_DATA_SA_Crash.csv")
Crash4 = sc.textFile("2018_DATA_SA_Crash.csv")
Crash5 = sc.textFile("2019_DATA_SA_Crash.csv")

# Sequentially merge Crash1, Crash3, Crash4, and then Crash5 into Crash1
CrashA = Crash1.union(Crash2)
CrashB = CrashA.union(Crash3)
CrashC = CrashB.union(Crash4)
Crash = CrashC.union(Crash5)

# Identify the header row
header = Crash.first()

Crash = Crash.filter(lambda x: x != header).map(lambda x: (x.split(',')))

# %%
Suburbs = sorted(set(list(Crash.map(lambda x: x[2]).collect())))

# %%
# Shorten the 2 RDDs to only include relevant fields to increase responsiveness
Units241 = Units.map(lambda x: (x[0], (x[7],x[8],x[11])))
Crash241 = Crash.map(lambda x: (x[0], (x[2],x[4],x[6],x[10],x[11],x[12],x[13],x[14])))

# %% [markdown]
# ## [RDD] 2.4.1

# %% [markdown]
# In the Crash CSV, some unfortunate formatting such as the inclusion of a comma WITHIN a particular `LGA Name` value ("CC OF NORWOOD,PAYNEHAM & ST PETERS") meant that RDD Operations were not able to easily process an identical schema for every `LGA Name`. To combat this, I processed the offending rows separately and simply joined the results at the end. As a result, both sets of operations differ slightly in index values used, but are otherwise entirely identical in terms of input and output.

# %%
# %%time

# List of invalid values that are filtered out
# Values marked 'UNKNOWN' etc are left in, because those are not wrong, simply unknown for other reasons, and are part of a valid record
invalidValues = ['""'," ","",''""'','"XXX"']

# Join the 2 RDDs
CrashUnitsRDD = Crash241\
.join(Units241)

# Filter for Adelaide, and continually append the request values to one another using Python strings
CrashUnitsList1 = CrashUnitsRDD\
.filter(lambda x: x[1][0][0]=='"ADELAIDE"')\
.filter(lambda x: x[1][1][1] not in invalidValues)\
.filter(lambda x: x[1][1][2] != '')\
.map(lambda x:\
     str(x[1][0][3]).strip('""')\
     +'-'+str(x[1][0][4]).strip('""')\
     +'-'+str(x[1][0][5]).strip('""')\
     +', '+str(x[1][0][6]).strip('""')\
     +', '+str(x[1][0][2]).strip('""')\
     +', '+str(x[1][1][0]).strip('""')\
     +', '+str(x[1][1][1]).strip('""')\
     +', '+str(x[1][1][2]).strip('""'))\
.collect()

# Repeat the same process as above, but including an additional filter for "CC OF NORWOOD,PAYNEHAM & ST PETERS".
# Some of the indexing values also differ as a result of the incorrect formatting
CrashUnitsList2 =CrashUnitsRDD\
.filter(lambda x: x[1][0][0]=='"ADELAIDE"')\
.filter(lambda x: x[1][0][1]=='"CC OF NORWOOD')\
.filter(lambda x: x[1][1][1] not in invalidValues)\
.filter(lambda x: x[1][1][2] != '')\
.map(lambda x:\
     str(x[1][0][4]).strip('""')\
     +'-'+str(x[1][0][5]).strip('""')\
     +'-'+str(x[1][0][6]).strip('""')\
     +', '+str(x[1][0][7]).strip('""')\
     +', '+str(x[1][0][2]).strip('""')\
     +', '+str(x[1][1][0]).strip('""')\
     +', '+str(x[1][1][1]).strip('""')\
     +', '+str(x[1][1][2]).strip('""'))\
.collect()
# Out:
# CPU times: user 39.1 ms, sys: 5.53 ms, total: 44.6 ms
# Wall time: 2.46 s

# %%
# For better readability, present the above RDDs as a Pandas Dataframe

# First, concatenate the 2 RDDs
data = CrashUnitsList1 + CrashUnitsList2

# Split the list values, and create a Pandas DataFrame
df = pd.DataFrame([x.split(',') for x in data])

# Rename the columns
df = df.rename(columns={0: "Date", 1: "Time", 2: "Casualties", 3:"Gender", 4:"Age", 5:"Licence Type"})
df
# Out:
#                        Date       Time Casualties   Gender   Age  \
# 0       2015-January-Friday   06:10 pm          1   Female   035
# 1       2015-January-Friday   06:10 pm          1   Female   037
# 2       2015-January-Friday   05:00 pm          0     Male   041
# 3      2015-January-Tuesday   03:10 pm          0   Female   044
# 4      2015-January-Tuesday   03:10 pm          0     Male   061
# ...                     ...        ...        ...      ...   ...
# 4498  2016-January-Thursday   04:30 pm          2     Male   017
# 4499  2016-January-Thursday   04:30 pm          2   Female   029
# 4500    2019-October-Friday   11:00 am          2     Male   063
# 4501    2016-October-Sunday   09:35 pm          2     Male   025
# 4502  2019-January-Thursday   05:13 pm          2     Male   023
#
#          Licence Type
# 0                Full
# 1                Full
# 2                Full
# 3                Full
# 4                Full
# ...               ...
# 4498   Provisional 1
# 4499             Full
# 4500             Full
# 4501          Unknown
# 4502             Full
#
# [4503 rows x 6 columns]

# %% [markdown]
# ## [RDD] 2.4.2

# %%
Units242 = Units.map(lambda x: (x[0], (x[7],x[8],x[11])))
Crash242 = Crash.map(lambda x: (x[0], (x[2],x[4],x[6],x[10],x[11],x[12],x[13],x[14])))

# %%
# %%time

# Collect an alphabetically set of all unique Suburbs identified in the Crash RDD

# For each unique suburb:
for suburb in Suburbs:

    # Join the 2 RDDs, filter for the suburb in question, and filter for an 'Unlicenced' Licence Type
    CrashUnits = Crash242\
    .join(Units242)\
    .filter(lambda x: x[1][0][0] == suburb)\
    .filter(lambda x: x[1][1][-1] == '"Unlicenced"')
    
    # Preliminarily stop the loop if there are no 'Unlicenced' Licence Type crashes for that suburb
    if len(CrashUnits.collect())==0:
        print ("['SUBURB:",suburb,", CASUALTIES: 0']")
        
    # ReduceByKey on (suburb,casualties) for each such combination found per row for the suburb in question
    # This gives (suburb, total casualties for the suburb)
    else:
        CrashUnits = CrashUnits\
        .map(lambda x: (x[1][0][0], x[1][0][2]))\
        .reduceByKey(lambda x,y: (int(x)+(int(y))))\
        .map(lambda x: 'SUBURB: '+suburb+', CASUALTIES: '+str(x[1]))            

        print(CrashUnits.collect())
# Out:
# ['SUBURB: "  PARAFIELD" , CASUALTIES: 0']
# ['SUBURB: "ABERFOYLE PARK", CASUALTIES: 1']
# ['SUBURB: "ABMINGA STATION" , CASUALTIES: 0']
# ['SUBURB: "ADELAIDE AIRPORT" , CASUALTIES: 0']
# ['SUBURB: "ADELAIDE", CASUALTIES: 19']
# ['SUBURB: "AGERY" , CASUALTIES: 0']
# ['SUBURB: "ALAWOONA" , CASUALTIES: 0']
# ['SUBURB: "ALBERT PARK", CASUALTIES: 2']
# ['SUBURB: "ALBERTON", CASUALTIES: 2']
# ['SUBURB: "ALDGATE" , CASUALTIES: 0']
# ['SUBURB: "ALDINGA BEACH", CASUALTIES: 2']
# ['SUBURB: "ALDINGA", CASUALTIES: 3']
# ['SUBURB: "ALFORD" , CASUALTIES: 0']
# ['SUBURB: "ALLANDALE STATION" , CASUALTIES: 0']
# ['SUBURB: "ALLENBY GARDENS", CASUALTIES: 2']
# ['SUBURB: "ALLENDALE EAST", CASUALTIES: 1']
# ['SUBURB: "ALLENDALE NORTH" , CASUALTIES: 0']
# ['SUBURB: "ALMA", CASUALTIES: 0']
# ['SUBURB: "ALPANA" , CASUALTIES: 0']
# ['SUBURB: "ALTONA" , CASUALTIES: 0']
# ['SUBURB: "AMATA", CASUALTIES: 1']
# ['SUBURB: "AMERICAN RIVER" , CASUALTIES: 0']
# ['SUBURB: "ANAMA" , CASUALTIES: 0']
# ['SUBURB: "ANANGU PITJANTJATJARA YANKUNYTJATARA", CASUALTIES: 2']
# ['SUBURB: "ANANGU PITJANTJATJARA YANKUNYTJATJARA", CASUALTIES: 0']
# ['SUBURB: "ANDAMOOKA" , CASUALTIES: 0']
# ['SUBURB: "ANDREWS FARM", CASUALTIES: 12']
# ['SUBURB: "ANDREWS", CASUALTIES: 0']
# ['SUBURB: "ANGAS PLAINS" , CASUALTIES: 0']
# ['SUBURB: "ANGASTON", CASUALTIES: 2']
# ['SUBURB: "ANGLE PARK", CASUALTIES: 0']
# ['SUBURB: "ANGLE VALE", CASUALTIES: 5']
# ['SUBURB: "ANNA CREEK", CASUALTIES: 0']
# ['SUBURB: "ANNADALE", CASUALTIES: 1']
# ['SUBURB: "ANTECHAMBER BAY" , CASUALTIES: 0']
# ['SUBURB: "APAMURRA" , CASUALTIES: 0']
# ['SUBURB: "APPILA" , CASUALTIES: 0']
# ['SUBURB: "APY", CASUALTIES: 3']
# ['SUBURB: "ARCKARINGA" , CASUALTIES: 0']
# ['SUBURB: "ARCOONA" , CASUALTIES: 0']
# ['SUBURB: "ARDROSSAN", CASUALTIES: 0']
# ['SUBURB: "ARKAROOLA" , CASUALTIES: 0']
# ['SUBURB: "ARMAGH", CASUALTIES: 1']
# ['SUBURB: "ARNO BAY" , CASUALTIES: 0']
# ['SUBURB: "ARTHURTON" , CASUALTIES: 0']
# ['SUBURB: "ASCOT PAR" , CASUALTIES: 0']
# ['SUBURB: "ASCOT PARK", CASUALTIES: 2']
# ['SUBURB: "ASHBOURNE" , CASUALTIES: 0']
# ['SUBURB: "ASHFORD", CASUALTIES: 1']
# ['SUBURB: "ASHTON", CASUALTIES: 0']
# ['SUBURB: "ASHVILLE", CASUALTIES: 2']
# ['SUBURB: "ATHELSTONE", CASUALTIES: 0']
# ['SUBURB: "ATHOL PARK", CASUALTIES: 1']
# ['SUBURB: "AUBURN", CASUALTIES: 1']
# ['SUBURB: "AULDANA" , CASUALTIES: 0']
# ['SUBURB: "AUSTRALIA PLAINS" , CASUALTIES: 0']
# ['SUBURB: "AVENUE RANGE" , CASUALTIES: 0']
# ['SUBURB: "AVON" , CASUALTIES: 0']
# ['SUBURB: "BACK VALLEY" , CASUALTIES: 0']
# ['SUBURB: "BAGOT WELL" , CASUALTIES: 0']
# ['SUBURB: "BAIRD BAY" , CASUALTIES: 0']
# ['SUBURB: "BAKARA WELL" , CASUALTIES: 0']
# ['SUBURB: "BALAKLAVA" , CASUALTIES: 0']
# ['SUBURB: "BALD HILLS" , CASUALTIES: 0']
# ['SUBURB: "BALGOWAN" , CASUALTIES: 0']
# ['SUBURB: "BALHANNAH", CASUALTIES: 4']
# ['SUBURB: "BANGHAM" , CASUALTIES: 0']
# ['SUBURB: "BANGOR" , CASUALTIES: 0']
# ['SUBURB: "BANKSIA PARK" , CASUALTIES: 0']
# ['SUBURB: "BARABBA" , CASUALTIES: 0']
# ['SUBURB: "BARATTA" , CASUALTIES: 0']
# ['SUBURB: "BARINIA" , CASUALTIES: 0']
# ['SUBURB: "BARMERA", CASUALTIES: 0']
# ['SUBURB: "BARNA" , CASUALTIES: 0']
# ['SUBURB: "BARNDIOOTA" , CASUALTIES: 0']
# ['SUBURB: "BAROOTA" , CASUALTIES: 0']
# ['SUBURB: "BAROSSA GOLDFIELDS" , CASUALTIES: 0']
# ['SUBURB: "BASKET RANGE", CASUALTIES: 0']
# ['SUBURB: "BAUDIN BEACH", CASUALTIES: 4']
# ['SUBURB: "BEACHPORT", CASUALTIES: 1']
# ['SUBURB: "BEAUFORT", CASUALTIES: 1']
# ['SUBURB: "BEAUMONT" , CASUALTIES: 0']
# ['SUBURB: "BEDFORD PARK", CASUALTIES: 11']
# ['SUBURB: "BEETALOO VALLEY" , CASUALTIES: 0']
# ['SUBURB: "BELAIR", CASUALTIES: 1']
# ['SUBURB: "BELALIE EAST" , CASUALTIES: 0']
# ['SUBURB: "BELALIE NORTH" , CASUALTIES: 0']
# ['SUBURB: "BELLEVUE HEIGHTS" , CASUALTIES: 0']
# ['SUBURB: "BELTANA STATION" , CASUALTIES: 0']
# ['SUBURB: "BELTANA" , CASUALTIES: 0']
# ['SUBURB: "BELTON" , CASUALTIES: 0']
# ['SUBURB: "BELVIDERE" , CASUALTIES: 0']
# ['SUBURB: "BENBOURNIE" , CASUALTIES: 0']
# ['SUBURB: "BERRI", CASUALTIES: 3']
# ['SUBURB: "BETHANY", CASUALTIES: 1']
# ['SUBURB: "BETHEL" , CASUALTIES: 0']
# ['SUBURB: "BEULAH PARK", CASUALTIES: 4']
# ['SUBURB: "BEVERLEY", CASUALTIES: 1']
# ['SUBURB: "BIBARINGA", CASUALTIES: 1']
# ['SUBURB: "BIGGS FLAT" , CASUALTIES: 0']
# ['SUBURB: "BILLIATT" , CASUALTIES: 0']
# ['SUBURB: "BINDARRAH" , CASUALTIES: 0']
# ['SUBURB: "BINNUM", CASUALTIES: 1']
# ['SUBURB: "BIRCHMORE" , CASUALTIES: 0']
# ['SUBURB: "BIRDWOOD", CASUALTIES: 0']
# ['SUBURB: "BIRKENHEAD", CASUALTIES: 2']
# ['SUBURB: "BLACK FOREST" , CASUALTIES: 0']
# ['SUBURB: "BLACK HILL" , CASUALTIES: 0']
# ['SUBURB: "BLACK POINT" , CASUALTIES: 0']
# ['SUBURB: "BLACK ROCK" , CASUALTIES: 0']
# ['SUBURB: "BLACK SPRINGS" , CASUALTIES: 0']
# ['SUBURB: "BLACKFELLOWS CAVES" , CASUALTIES: 0']
# ['SUBURB: "BLACKFELLOWS CREEK" , CASUALTIES: 0']
# ['SUBURB: "BLACKWOOD", CASUALTIES: 1']
# ['SUBURB: "BLAIR ATHOL", CASUALTIES: 3']
# ['SUBURB: "BLAKEVIEW", CASUALTIES: 3']
# ['SUBURB: "BLAKISTON" , CASUALTIES: 0']
# ['SUBURB: "BLANCHETOWN" , CASUALTIES: 0']
# ['SUBURB: "BLETCHLEY" , CASUALTIES: 0']
# ['SUBURB: "BLEWITT SPRINGS" , CASUALTIES: 0']
# ['SUBURB: "BLINMAN" , CASUALTIES: 0']
# ['SUBURB: "BLYTH", CASUALTIES: 1']
# ['SUBURB: "BOCONNOC PARK" , CASUALTIES: 0']
# ['SUBURB: "BOLIVAR", CASUALTIES: 3']
# ['SUBURB: "BOLLARDS LAGOON" , CASUALTIES: 0']
# ['SUBURB: "BOLTO", CASUALTIES: 0']
# ['SUBURB: "BON BON" , CASUALTIES: 0']
# ['SUBURB: "BOOBOROWIE" , CASUALTIES: 0']
# ['SUBURB: "BOOKABIE", CASUALTIES: 1']
# ['SUBURB: "BOOKPURNONG" , CASUALTIES: 0']
# ['SUBURB: "BOOL LAGOON" , CASUALTIES: 0']
# ['SUBURB: "BOOLEROO CENTRE" , CASUALTIES: 0']
# ['SUBURB: "BOORS PLAIN" , CASUALTIES: 0']
# ['SUBURB: "BORDERTOWN SOUTH" , CASUALTIES: 0']
# ['SUBURB: "BORDERTOWN", CASUALTIES: 3']
# ['SUBURB: "BORRIKA", CASUALTIES: 0']
# ['SUBURB: "BOSTON" , CASUALTIES: 0']
# ['SUBURB: "BOWDEN", CASUALTIES: 1']
# ['SUBURB: "BOWER", CASUALTIES: 1']
# ['SUBURB: "BOWHILL" , CASUALTIES: 0']
# ['SUBURB: "BOWMANS" , CASUALTIES: 0']
# ['SUBURB: "BRADBURY" , CASUALTIES: 0']
# ['SUBURB: "BRADY CREEK" , CASUALTIES: 0']
# ['SUBURB: "BRAHMA LODGE", CASUALTIES: 2']
# ['SUBURB: "BRAY" , CASUALTIES: 0']
# ['SUBURB: "BRIDGEWATER", CASUALTIES: 2']
# ['SUBURB: "BRIGHTON", CASUALTIES: 2']
# ['SUBURB: "BRIMBAGO" , CASUALTIES: 0']
# ['SUBURB: "BRINKLEY", CASUALTIES: 0']
# ['SUBURB: "BRINKWORTH" , CASUALTIES: 0']
# ['SUBURB: "BROADVIEW", CASUALTIES: 5']
# ['SUBURB: "BROADWOOD" , CASUALTIES: 0']
# ['SUBURB: "BROMPTON", CASUALTIES: 2']
# ['SUBURB: "BROOKLYN PARK", CASUALTIES: 7']
# ['SUBURB: "BROUGHTON RIVER VALLEY" , CASUALTIES: 0']
# ['SUBURB: "BROWN HILL CREEK", CASUALTIES: 0']
# ['SUBURB: "BROWNLOW", CASUALTIES: 0']
# ['SUBURB: "BRUCE" , CASUALTIES: 0']
# ['SUBURB: "BRUKUNGA", CASUALTIES: 1']
# ['SUBURB: "BUCHANAN" , CASUALTIES: 0']
# ['SUBURB: "BUCHFELDE" , CASUALTIES: 0']
# ['SUBURB: "BUCKLAND PARK", CASUALTIES: 1']
# ['SUBURB: "BUCKLEBOO" , CASUALTIES: 0']
# ['SUBURB: "BUGLE RANGES" , CASUALTIES: 0']
# ['SUBURB: "BULGUNNIA" , CASUALTIES: 0']
# ['SUBURB: "BULL CREEK" , CASUALTIES: 0']
# ['SUBURB: "BULLOO CREEK" , CASUALTIES: 0']
# ['SUBURB: "BUMBUNGA" , CASUALTIES: 0']
# ['SUBURB: "BUNDALEER NORTH" , CASUALTIES: 0']
# ['SUBURB: "BUNDEY" , CASUALTIES: 0']
# ['SUBURB: "BUNGAMA" , CASUALTIES: 0']
# ['SUBURB: "BUNGAREE" , CASUALTIES: 0']
# ['SUBURB: "BURDETT" , CASUALTIES: 0']
# ['SUBURB: "BURNSIDE" , CASUALTIES: 0']
# ['SUBURB: "BURR WELL", CASUALTIES: 0']
# ['SUBURB: "BURRA EASTERN DISTRICTS" , CASUALTIES: 0']
# ['SUBURB: "BURRA", CASUALTIES: 7']
# ['SUBURB: "BURRUNGULE" , CASUALTIES: 0']
# ['SUBURB: "BURTON", CASUALTIES: 10']
# ['SUBURB: "BUTE", CASUALTIES: 0']
# ['SUBURB: "BUTLER" , CASUALTIES: 0']
# ['SUBURB: "CADELL" , CASUALTIES: 0']
# ['SUBURB: "CADGEE" , CASUALTIES: 0']
# ['SUBURB: "CALCA" , CASUALTIES: 0']
# ['SUBURB: "CALIPH" , CASUALTIES: 0']
# ['SUBURB: "CALLANNA" , CASUALTIES: 0']
# ['SUBURB: "CALLINGTON", CASUALTIES: 4']
# ['SUBURB: "CALOMBA", CASUALTIES: 0']
# ['SUBURB: "CALOOTE", CASUALTIES: 0']
# ['SUBURB: "CALPERUM STATION" , CASUALTIES: 0']
# ['SUBURB: "CALTOWIE WEST" , CASUALTIES: 0']
# ['SUBURB: "CALTOWIE" , CASUALTIES: 0']
# ['SUBURB: "CAMBRAI" , CASUALTIES: 0']
# ['SUBURB: "CAMDEN PARK", CASUALTIES: 1']
# ['SUBURB: "CAMPBELLTOWN", CASUALTIES: 2']
# ['SUBURB: "CANNAWIGARA" , CASUALTIES: 0']
# ['SUBURB: "CANUNDA" , CASUALTIES: 0']
# ['SUBURB: "CAPE BORDA" , CASUALTIES: 0']
# ['SUBURB: "CAPE JERVIS" , CASUALTIES: 0']
# ['SUBURB: "CARAWA", CASUALTIES: 2']
# ['SUBURB: "CAREY GULLY", CASUALTIES: 1']
# ['SUBURB: "CAROLINE" , CASUALTIES: 0']
# ['SUBURB: "CARPENTER ROCKS" , CASUALTIES: 0']
# ['SUBURB: "CARRICKALINGA" , CASUALTIES: 0']
# ['SUBURB: "CARRIETON" , CASUALTIES: 0']
# ['SUBURB: "CARRIEWERLOO" , CASUALTIES: 0']
# ['SUBURB: "CASSINI", CASUALTIES: 1']
# ['SUBURB: "CASTAMBUL" , CASUALTIES: 0']
# ['SUBURB: "CAVAN", CASUALTIES: 1']
# ['SUBURB: "CAVENAGH" , CASUALTIES: 0']
# ['SUBURB: "CAVETON" , CASUALTIES: 0']
# ['SUBURB: "CEDUNA", CASUALTIES: 2']
# ['SUBURB: "CHAFFEY", CASUALTIES: 1']
# ['SUBURB: "CHAIN OF PONDS", CASUALTIES: 6']
# ['SUBURB: "CHANDADA" , CASUALTIES: 0']
# ['SUBURB: "CHANDLERS HILL", CASUALTIES: 1']
# ['SUBURB: "CHAPEL HILL" , CASUALTIES: 0']
# ['SUBURB: "CHAPMAN BORE" , CASUALTIES: 0']
# ['SUBURB: "CHARLESTON" , CASUALTIES: 0']
# ['SUBURB: "CHARRA" , CASUALTIES: 0']
# ['SUBURB: "CHELTENHAM", CASUALTIES: 4']
# ['SUBURB: "CHELTENHEM" , CASUALTIES: 0']
# ['SUBURB: "CHERRY GARDENS" , CASUALTIES: 0']
# ['SUBURB: "CHERRYVILLE" , CASUALTIES: 0']
# ['SUBURB: "CHINBINGA" , CASUALTIES: 0']
# ['SUBURB: "CHINBINGINA" , CASUALTIES: 0']
# ['SUBURB: "CHITON" , CASUALTIES: 0']
# ['SUBURB: "CHOWILLA" , CASUALTIES: 0']
# ['SUBURB: "CHRISTIE BEACH" , CASUALTIES: 0']
# ['SUBURB: "CHRISTIE DOWNS", CASUALTIES: 5']
# ['SUBURB: "CHRISTIES BEACH", CASUALTIES: 2']
# ['SUBURB: "CLAPHAM" , CASUALTIES: 0']
# ['SUBURB: "CLARE", CASUALTIES: 0']
# ['SUBURB: "CLARENCE GARDENS", CASUALTIES: 2']
# ['SUBURB: "CLARENCE PARK", CASUALTIES: 0']
# ['SUBURB: "CLARENDON", CASUALTIES: 0']
# ['SUBURB: "CLAY WELLS", CASUALTIES: 1']
# ['SUBURB: "CLAYTON BAY" , CASUALTIES: 0']
# ['SUBURB: "CLEARVIEW", CASUALTIES: 0']
# ['SUBURB: "CLELAND", CASUALTIES: 1']
# ['SUBURB: "CLEMENTS GAP" , CASUALTIES: 0']
# ['SUBURB: "CLEVE" , CASUALTIES: 0']
# ['SUBURB: "CLIFTON HILLS STATION" , CASUALTIES: 0']
# ['SUBURB: "CLINTON" , CASUALTIES: 0']
# ['SUBURB: "CLOVELLY PARK", CASUALTIES: 1']
# ['SUBURB: "COBDOGLA" , CASUALTIES: 0']
# ['SUBURB: "COCKALEECHIE" , CASUALTIES: 0']
# ['SUBURB: "COCKATOO VALLEY", CASUALTIES: 0']
# ['SUBURB: "COCKBURN" , CASUALTIES: 0']
# ['SUBURB: "COFFIN BAY", CASUALTIES: 1']
# ['SUBURB: "COLEBATCH" , CASUALTIES: 0']
# ['SUBURB: "COLES" , CASUALTIES: 0']
# ['SUBURB: "COLLEGE PARK", CASUALTIES: 2']
# ['SUBURB: "COLLEY" , CASUALTIES: 0']
# ['SUBURB: "COLLINSFIELD" , CASUALTIES: 0']
# ['SUBURB: "COLLINSVILLE" , CASUALTIES: 0']
# ['SUBURB: "COLLINSWOOD", CASUALTIES: 2']
# ['SUBURB: "COLONEL LIGHT GARDENS", CASUALTIES: 0']
# ['SUBURB: "COLTON" , CASUALTIES: 0']
# ['SUBURB: "COMMISSARIAT POINT", CASUALTIES: 2']
# ['SUBURB: "COMMONWEALTH HILL" , CASUALTIES: 0']
# ['SUBURB: "COMPTON", CASUALTIES: 0']
# ['SUBURB: "CONCORDIA" , CASUALTIES: 0']
# ['SUBURB: "CONDOWIE", CASUALTIES: 0']
# ['SUBURB: "CONMURRA", CASUALTIES: 1']
# ['SUBURB: "COOBER PEDY", CASUALTIES: 7']
# ['SUBURB: "COOBOWIE" , CASUALTIES: 0']
# ['SUBURB: "COOKE PLAINS" , CASUALTIES: 0']
# ['SUBURB: "COOLTONG" , CASUALTIES: 0']
# ['SUBURB: "COOMANDOOK" , CASUALTIES: 0']
# ['SUBURB: "COOMBE" , CASUALTIES: 0']
# ['SUBURB: "COOMOOROO" , CASUALTIES: 0']
# ['SUBURB: "COOMUNGA" , CASUALTIES: 0']
# ['SUBURB: "COONALPYN" , CASUALTIES: 0']
# ['SUBURB: "COONAMIA" , CASUALTIES: 0']
# ['SUBURB: "COONAWARRA" , CASUALTIES: 0']
# ['SUBURB: "COONDAMBO", CASUALTIES: 0']
# ['SUBURB: "COORABIE" , CASUALTIES: 0']
# ['SUBURB: "COORONG" , CASUALTIES: 0']
# ['SUBURB: "COOTRA" , CASUALTIES: 0']
# ['SUBURB: "COPLEY" , CASUALTIES: 0']
# ['SUBURB: "CORDILLO DOWNS" , CASUALTIES: 0']
# ['SUBURB: "CORNY POINT" , CASUALTIES: 0']
# ['SUBURB: "COROMANDEL EAST", CASUALTIES: 1']
# ['SUBURB: "COROMANDEL VALLEY" , CASUALTIES: 0']
# ['SUBURB: "CORTLINYE" , CASUALTIES: 0']
# ['SUBURB: "CORUNNA STATION" , CASUALTIES: 0']
# ['SUBURB: "COULTA" , CASUALTIES: 0']
# ['SUBURB: "COWANDILLA", CASUALTIES: 1']
# ['SUBURB: "COWELL", CASUALTIES: 1']
# ['SUBURB: "COWIRRA" , CASUALTIES: 0']
# ['SUBURB: "CRADOCK" , CASUALTIES: 0']
# ['SUBURB: "CRAFERS WEST", CASUALTIES: 1']
# ['SUBURB: "CRAFERS", CASUALTIES: 1']
# ['SUBURB: "CRAIGBURN FARM" , CASUALTIES: 0']
# ['SUBURB: "CRAIGMORE", CASUALTIES: 2']
# ['SUBURB: "CRESCENT", CASUALTIES: 1']
# ['SUBURB: "CROMER" , CASUALTIES: 0']
# ['SUBURB: "CROSS ROADS" , CASUALTIES: 0']
# ['SUBURB: "CROYDON PARK", CASUALTIES: 1']
# ['SUBURB: "CROYDON", CASUALTIES: 4']
# ['SUBURB: "CRYSTAL BROOK", CASUALTIES: 0']
# ['SUBURB: "CUDLEE CREEK", CASUALTIES: 2']
# ['SUBURB: "CULBURRA" , CASUALTIES: 0']
# ['SUBURB: "CULTANA", CASUALTIES: 1']
# ['SUBURB: "CUMBERLAND PARK", CASUALTIES: 0']
# ['SUBURB: "CUMMINS", CASUALTIES: 0']
# ['SUBURB: "CUNGENA" , CASUALTIES: 0']
# ['SUBURB: "CUNLIFFE", CASUALTIES: 1']
# ['SUBURB: "CUNNINGHAM" , CASUALTIES: 0']
# ['SUBURB: "CURRAMULKA" , CASUALTIES: 0']
# ['SUBURB: "CURRENCY CREEK", CASUALTIES: 5']
# ['SUBURB: "CUSTON" , CASUALTIES: 0']
# ['SUBURB: "CUTTLEFISH BAY" , CASUALTIES: 0']
# ['SUBURB: "CYGNET RIVER", CASUALTIES: 1']
# ['SUBURB: "D'ESTREES BAY" , CASUALTIES: 0']
# ['SUBURB: "DARKE PEAK" , CASUALTIES: 0']
# ['SUBURB: "DARLINGTON", CASUALTIES: 1']
# ['SUBURB: "DAVENPORT" , CASUALTIES: 0']
# ['SUBURB: "DAVEYSTON" , CASUALTIES: 0']
# ['SUBURB: "DAVOREN PARK", CASUALTIES: 8']
# ['SUBURB: "DAW PARK", CASUALTIES: 0']
# ['SUBURB: "DAWESLEY", CASUALTIES: 5']
# ['SUBURB: "DAWSON" , CASUALTIES: 0']
# ['SUBURB: "DE ROSE HILL" , CASUALTIES: 0']
# ['SUBURB: "DEEP CREEK" , CASUALTIES: 0']
# ['SUBURB: "DELAMERE" , CASUALTIES: 0']
# ['SUBURB: "DENIAL BAY" , CASUALTIES: 0']
# ['SUBURB: "DERNANCOURT", CASUALTIES: 2']
# ['SUBURB: "DEVLINS POUND" , CASUALTIES: 0']
# ['SUBURB: "DEVON PARK" , CASUALTIES: 0']
# ['SUBURB: "DINGABLEDINGA" , CASUALTIES: 0']
# ['SUBURB: "DIREK", CASUALTIES: 4']
# ['SUBURB: "DISMAL SWAMP" , CASUALTIES: 0']
# ['SUBURB: "DONOVANS" , CASUALTIES: 0']
# ['SUBURB: "DORSET VALE" , CASUALTIES: 0']
# ['SUBURB: "DOUGLAS POINT", CASUALTIES: 1']
# ['SUBURB: "DOVER GARDENS" , CASUALTIES: 0']
# ['SUBURB: "DOWLINGVILLE" , CASUALTIES: 0']
# ['SUBURB: "DRY CREEK", CASUALTIES: 18']
# ['SUBURB: "DUBLIN" , CASUALTIES: 0']
# ['SUBURB: "DUCK PONDS" , CASUALTIES: 0']
# ['SUBURB: "DUDLEY EAST" , CASUALTIES: 0']
# ['SUBURB: "DUDLEY PARK", CASUALTIES: 0']
# ['SUBURB: "DUDLEY WEST" , CASUALTIES: 0']
# ['SUBURB: "DULKANINNA" , CASUALTIES: 0']
# ['SUBURB: "DULWICH", CASUALTIES: 0']
# ['SUBURB: "DUNCAN" , CASUALTIES: 0']
# ['SUBURB: "DUTTON" , CASUALTIES: 0']
# ['SUBURB: "EAST MOONTA" , CASUALTIES: 0']
# ['SUBURB: "EASTWOOD" , CASUALTIES: 0']
# ['SUBURB: "EBA" , CASUALTIES: 0']
# ['SUBURB: "EBENEZER" , CASUALTIES: 0']
# ['SUBURB: "ECHUNGA", CASUALTIES: 1']
# ['SUBURB: "EDEN HILLS" , CASUALTIES: 0']
# ['SUBURB: "EDEN VALLEY" , CASUALTIES: 0']
# ['SUBURB: "EDILLILIE" , CASUALTIES: 0']
# ['SUBURB: "EDINBURGH NORTH", CASUALTIES: 1']
# ['SUBURB: "EDINBURGH", CASUALTIES: 2']
# ['SUBURB: "EDITHBURGH" , CASUALTIES: 0']
# ['SUBURB: "EDWARDSTOWN", CASUALTIES: 6']
# ['SUBURB: "EIGHT MILE CREEK", CASUALTIES: 1']
# ['SUBURB: "ELIZABETH DOWNS", CASUALTIES: 6']
# ['SUBURB: "ELIZABETH EAST", CASUALTIES: 9']
# ['SUBURB: "ELIZABETH GROVE", CASUALTIES: 9']
# ['SUBURB: "ELIZABETH NORTH", CASUALTIES: 6']
# ['SUBURB: "ELIZABETH PARK", CASUALTIES: 10']
# ['SUBURB: "ELIZABETH SOUTH", CASUALTIES: 8']
# ['SUBURB: "ELIZABETH VALE", CASUALTIES: 4']
# ['SUBURB: "ELIZABETH", CASUALTIES: 3']
# ['SUBURB: "ELLISTON" , CASUALTIES: 0']
# ['SUBURB: "ELWOMPLE" , CASUALTIES: 0']
# ['SUBURB: "EMU BAY" , CASUALTIES: 0']
# ['SUBURB: "EMU DOWNS" , CASUALTIES: 0']
# ['SUBURB: "ENCOUNTER BAY", CASUALTIES: 1']
# ['SUBURB: "ENFIELD", CASUALTIES: 12']
# ['SUBURB: "ERINDALE" , CASUALTIES: 0']
# ['SUBURB: "ERINGA", CASUALTIES: 1']
# ['SUBURB: "ERITH" , CASUALTIES: 0']
# ['SUBURB: "ETADUNNA" , CASUALTIES: 0']
# ['SUBURB: "ETHELTON", CASUALTIES: 1']
# ['SUBURB: "ETTRICK", CASUALTIES: 1']
# ['SUBURB: "EUDUNDA" , CASUALTIES: 0']
# ['SUBURB: "EURELIA" , CASUALTIES: 0']
# ['SUBURB: "EUROMINA" , CASUALTIES: 0']
# ['SUBURB: "EVANDALE" , CASUALTIES: 0']
# ['SUBURB: "EVANSTON GARDENS" , CASUALTIES: 0']
# ['SUBURB: "EVANSTON PARK", CASUALTIES: 3']
# ['SUBURB: "EVANSTON SOUTH", CASUALTIES: 0']
# ['SUBURB: "EVANSTON", CASUALTIES: 1']
# ['SUBURB: "EVARARD PARK" , CASUALTIES: 0']
# ['SUBURB: "EVERARD CENTRAL" , CASUALTIES: 0']
# ['SUBURB: "EVERARD PARK", CASUALTIES: 1']
# ['SUBURB: "EXETER" , CASUALTIES: 0']
# ['SUBURB: "EYRE", CASUALTIES: 5']
# ['SUBURB: "FAIRVIEW PARK", CASUALTIES: 0']
# ['SUBURB: "FARINA STATION" , CASUALTIES: 0']
# ['SUBURB: "FARM BEACH" , CASUALTIES: 0']
# ['SUBURB: "FARRELL FLAT", CASUALTIES: 0']
# ['SUBURB: "FELIXSTOW", CASUALTIES: 10']
# ['SUBURB: "FELIXTOWE" , CASUALTIES: 0']
# ['SUBURB: "FERRYDEN PARK", CASUALTIES: 2']
# ['SUBURB: "FIELD", CASUALTIES: 1']
# ['SUBURB: "FINDON", CASUALTIES: 6']
# ['SUBURB: "FINNISS", CASUALTIES: 2']
# ['SUBURB: "FIRLE", CASUALTIES: 6']
# ['SUBURB: "FISCHER" , CASUALTIES: 0']
# ['SUBURB: "FISHER" , CASUALTIES: 0']
# ['SUBURB: "FITZGERALD BAY", CASUALTIES: 1']
# ['SUBURB: "FITZORY" , CASUALTIES: 0']
# ['SUBURB: "FITZROY", CASUALTIES: 4']
# ['SUBURB: "FLAGSTAFF HILL", CASUALTIES: 3']
# ['SUBURB: "FLAXLEY" , CASUALTIES: 0']
# ['SUBURB: "FLAXMAN VALLEY" , CASUALTIES: 0']
# ['SUBURB: "FLINDERS CHASE" , CASUALTIES: 0']
# ['SUBURB: "FLINDERS PARK", CASUALTIES: 8']
# ['SUBURB: "FLINDERS RANGES" , CASUALTIES: 0']
# ['SUBURB: "FLORINA STATION" , CASUALTIES: 0']
# ['SUBURB: "FORDS" , CASUALTIES: 0']
# ['SUBURB: "FOREST RANGE" , CASUALTIES: 0']
# ['SUBURB: "FORESTVILLE", CASUALTIES: 1']
# ['SUBURB: "FORRESTON", CASUALTIES: 1']
# ['SUBURB: "FOUL BAY" , CASUALTIES: 0']
# ['SUBURB: "FOUNTAIN" , CASUALTIES: 0']
# ['SUBURB: "FOWLERS BAY" , CASUALTIES: 0']
# ['SUBURB: "FOX" , CASUALTIES: 0']
# ['SUBURB: "FRANCES" , CASUALTIES: 0']
# ['SUBURB: "FRANKTON" , CASUALTIES: 0']
# ['SUBURB: "FREELING", CASUALTIES: 3']
# ['SUBURB: "FREWVILLE", CASUALTIES: 0']
# ['SUBURB: "FULHAM GARDENS", CASUALTIES: 2']
# ['SUBURB: "FULHAM", CASUALTIES: 0']
# ['SUBURB: "FULLARTON", CASUALTIES: 0']
# ['SUBURB: "FURNER" , CASUALTIES: 0']
# ['SUBURB: "GAMMON RANGES" , CASUALTIES: 0']
# ['SUBURB: "GAWLER BELT", CASUALTIES: 0']
# ['SUBURB: "GAWLER EAST", CASUALTIES: 1']
# ['SUBURB: "GAWLER RIVER" , CASUALTIES: 0']
# ['SUBURB: "GAWLER SOUTH", CASUALTIES: 3']
# ['SUBURB: "GAWLER WEST", CASUALTIES: 3']
# ['SUBURB: "GAWLER", CASUALTIES: 1']
# ['SUBURB: "GEMMELLS" , CASUALTIES: 0']
# ['SUBURB: "GEORGETOWN", CASUALTIES: 2']
# ['SUBURB: "GEPPS CROSS", CASUALTIES: 4']
# ['SUBURB: "GERANIUM PLAINS" , CASUALTIES: 0']
# ['SUBURB: "GERANIUM" , CASUALTIES: 0']
# ['SUBURB: "GERARD" , CASUALTIES: 0']
# ['SUBURB: "GERMAN CREEK" , CASUALTIES: 0']
# ['SUBURB: "GERMEIN BAY" , CASUALTIES: 0']
# ['SUBURB: "GIDGEALPA" , CASUALTIES: 0']
# ['SUBURB: "GIFFORD HILL" , CASUALTIES: 0']
# ['SUBURB: "GILBERTON" , CASUALTIES: 0']
# ['SUBURB: "GILES CORNER" , CASUALTIES: 0']
# ['SUBURB: "GILLENTOWN" , CASUALTIES: 0']
# ['SUBURB: "GILLES DOWNS" , CASUALTIES: 0']
# ['SUBURB: "GILLES PLAINS", CASUALTIES: 7']
# ['SUBURB: "GILLMAN" , CASUALTIES: 0']
# ['SUBURB: "GLADSTONE", CASUALTIES: 0']
# ['SUBURB: "GLANDORE", CASUALTIES: 1']
# ['SUBURB: "GLANVILLE", CASUALTIES: 1']
# ['SUBURB: "GLEN OSMOND", CASUALTIES: 1']
# ['SUBURB: "GLENALTA" , CASUALTIES: 0']
# ['SUBURB: "GLENBURNIE" , CASUALTIES: 0']
# ['SUBURB: "GLENCOE" , CASUALTIES: 0']
# ['SUBURB: "GLENELG EAST", CASUALTIES: 2']
# ['SUBURB: "GLENELG NORTH", CASUALTIES: 4']
# ['SUBURB: "GLENELG SOUTH", CASUALTIES: 1']
# ['SUBURB: "GLENELG", CASUALTIES: 1']
# ['SUBURB: "GLENGOWRIE", CASUALTIES: 1']
# ['SUBURB: "GLENROY" , CASUALTIES: 0']
# ['SUBURB: "GLENSIDE", CASUALTIES: 2']
# ['SUBURB: "GLENUNGA", CASUALTIES: 0']
# ['SUBURB: "GLOBE DERBY PARK", CASUALTIES: 3']
# ['SUBURB: "GLOSSOP", CASUALTIES: 3']
# ['SUBURB: "GLYNDE", CASUALTIES: 7']
# ['SUBURB: "GOLDEN GROVE", CASUALTIES: 3']
# ['SUBURB: "GOLDEN HEIGHTS" , CASUALTIES: 0']
# ['SUBURB: "GOMERSAL", CASUALTIES: 0']
# ['SUBURB: "GOOD HOPE LANDING" , CASUALTIES: 0']
# ['SUBURB: "GOODWOOD" , CASUALTIES: 0']
# ['SUBURB: "GOOLWA BEACH", CASUALTIES: 1']
# ['SUBURB: "GOOLWA NORTH" , CASUALTIES: 0']
# ['SUBURB: "GOOLWA SOUTH", CASUALTIES: 0']
# ['SUBURB: "GOOLWA", CASUALTIES: 1']
# ['SUBURB: "GOSSE" , CASUALTIES: 0']
# ['SUBURB: "GOULD CREEK", CASUALTIES: 0']
# ['SUBURB: "GRACE PLAINS" , CASUALTIES: 0']
# ['SUBURB: "GRANGE", CASUALTIES: 1']
# ['SUBURB: "GREEN FIELDS", CASUALTIES: 2']
# ['SUBURB: "GREEN HILLS RANGE" , CASUALTIES: 0']
# ['SUBURB: "GREENACRES", CASUALTIES: 1']
# ['SUBURB: "GREENHILL", CASUALTIES: 0']
# ['SUBURB: "GREENOCK" , CASUALTIES: 0']
# ['SUBURB: "GREENWAYS" , CASUALTIES: 0']
# ['SUBURB: "GREENWITH", CASUALTIES: 1']
# ['SUBURB: "GULFVIEW HEIGHTS", CASUALTIES: 0']
# ['SUBURB: "GULFVIEW HIGHTS" , CASUALTIES: 0']
# ['SUBURB: "GULNARE" , CASUALTIES: 0']
# ['SUBURB: "GUMERACHA" , CASUALTIES: 0']
# ['SUBURB: "GURRA GURRA" , CASUALTIES: 0']
# ['SUBURB: "HACKHAM WEST", CASUALTIES: 6']
# ['SUBURB: "HACKHAM", CASUALTIES: 3']
# ['SUBURB: "HACKNEY", CASUALTIES: 8']
# ['SUBURB: "HAHNDORF", CASUALTIES: 2']
# ['SUBURB: "HAINES", CASUALTIES: 2']
# ['SUBURB: "HALBURY", CASUALTIES: 1']
# ['SUBURB: "HALIDON" , CASUALTIES: 0']
# ['SUBURB: "HALLELUJAH HILLS" , CASUALTIES: 0']
# ['SUBURB: "HALLETT COVE", CASUALTIES: 3']
# ['SUBURB: "HALLETT", CASUALTIES: 0']
# ['SUBURB: "HAMILTON" , CASUALTIES: 0']
# ['SUBURB: "HAMLEY BRIDGE", CASUALTIES: 1']
# ['SUBURB: "HAMPDEN" , CASUALTIES: 0']
# ['SUBURB: "HAMPSTEAD GARDENS", CASUALTIES: 0']
# ['SUBURB: "HANSBOROUGH" , CASUALTIES: 0']
# ['SUBURB: "HANSON" , CASUALTIES: 0']
# ['SUBURB: "HAPPY VALLEY", CASUALTIES: 5']
# ['SUBURB: "HARDWICKE BAY" , CASUALTIES: 0']
# ['SUBURB: "HARROGATE" , CASUALTIES: 0']
# ['SUBURB: "HART" , CASUALTIES: 0']
# ['SUBURB: "HARTLEY", CASUALTIES: 3']
# ['SUBURB: "HASLAM", CASUALTIES: 1']
# ['SUBURB: "HATHERLEIGH" , CASUALTIES: 0']
# ['SUBURB: "HAWKER", CASUALTIES: 0']
# ['SUBURB: "HAWSON" , CASUALTIES: 0']
# ['SUBURB: "HAWTHORN", CASUALTIES: 1']
# ['SUBURB: "HAWTHORNDENE", CASUALTIES: 0']
# ['SUBURB: "HAY FLAT" , CASUALTIES: 0']
# ['SUBURB: "HAY VALLEY" , CASUALTIES: 0']
# ['SUBURB: "HAYBOROUGH" , CASUALTIES: 0']
# ['SUBURB: "HAZELWOOD PARK", CASUALTIES: 2']
# ['SUBURB: "HEATHFIELD" , CASUALTIES: 0']
# ['SUBURB: "HEATHPOOL", CASUALTIES: 3']
# ['SUBURB: "HECTORVILLE", CASUALTIES: 0']
# ['SUBURB: "HENDON", CASUALTIES: 0']
# ['SUBURB: "HENLEY BEACH SOUTH", CASUALTIES: 2']
# ['SUBURB: "HENLEY BEACH", CASUALTIES: 1']
# ['SUBURB: "HEWETT" , CASUALTIES: 0']
# ['SUBURB: "HIGHBURY", CASUALTIES: 1']
# ['SUBURB: "HIGHGATE", CASUALTIES: 0']
# ['SUBURB: "HIGHLAND VALLEY" , CASUALTIES: 0']
# ['SUBURB: "HILL RIVER" , CASUALTIES: 0']
# ['SUBURB: "HILLBANK", CASUALTIES: 1']
# ['SUBURB: "HILLCREST", CASUALTIES: 0']
# ['SUBURB: "HILLIER", CASUALTIES: 3']
# ['SUBURB: "HILTABA" , CASUALTIES: 0']
# ['SUBURB: "HILTON", CASUALTIES: 1']
# ['SUBURB: "HINDMARSH ISLAND" , CASUALTIES: 0']
# ['SUBURB: "HINDMARSH TIERS" , CASUALTIES: 0']
# ['SUBURB: "HINDMARSH VALLEY", CASUALTIES: 2']
# ['SUBURB: "HINDMARSH", CASUALTIES: 2']
# ['SUBURB: "HINKS" , CASUALTIES: 0']
# ['SUBURB: "HOLDEN HILL", CASUALTIES: 9']
# ['SUBURB: "HOLDER SIDING" , CASUALTIES: 0']
# ['SUBURB: "HOLDER" , CASUALTIES: 0']
# ['SUBURB: "HOLOWILIENA SOUTH" , CASUALTIES: 0']
# ['SUBURB: "HOLOWILIENA" , CASUALTIES: 0']
# ['SUBURB: "HONITON" , CASUALTIES: 0']
# ['SUBURB: "HOPE FOREST" , CASUALTIES: 0']
# ['SUBURB: "HOPE GAP" , CASUALTIES: 0']
# ['SUBURB: "HOPE VALLEY", CASUALTIES: 0']
# ['SUBURB: "HORSNELL GULLY", CASUALTIES: 0']
# ['SUBURB: "HOSKIN CORNER", CASUALTIES: 0']
# ['SUBURB: "HOUGHTON", CASUALTIES: 3']
# ['SUBURB: "HOVE", CASUALTIES: 1']
# ['SUBURB: "HOYLETON" , CASUALTIES: 0']
# ['SUBURB: "HUDDLESTON" , CASUALTIES: 0']
# ['SUBURB: "HUMBUG SCRUB" , CASUALTIES: 0']
# ['SUBURB: "HUNTFIELD HEIGHTS", CASUALTIES: 3']
# ['SUBURB: "HYDE PARK", CASUALTIES: 0']
# ['SUBURB: "HYNAM" , CASUALTIES: 0']
# ['SUBURB: "INGLE FARM", CASUALTIES: 11']
# ['SUBURB: "INGLEWOOD", CASUALTIES: 0']
# ['SUBURB: "INGOMAR" , CASUALTIES: 0']
# ['SUBURB: "INKERMAN", CASUALTIES: 2']
# ['SUBURB: "INMAN VALLEY" , CASUALTIES: 0']
# ['SUBURB: "INNAMINCKA" , CASUALTIES: 0']
# ['SUBURB: "INNESTON", CASUALTIES: 2']
# ['SUBURB: "IRON KNOB" , CASUALTIES: 0']
# ['SUBURB: "IRONBANK", CASUALTIES: 0']
# ['SUBURB: "IRONSTONE" , CASUALTIES: 0']
# ['SUBURB: "IWANTJA", CASUALTIES: 2']
# ['SUBURB: "JABUK" , CASUALTIES: 0']
# ['SUBURB: "JAMESTOWN", CASUALTIES: 1']
# ['SUBURB: "JERICHO", CASUALTIES: 0']
# ['SUBURB: "JERUSALEM" , CASUALTIES: 0']
# ['SUBURB: "JERVOIS" , CASUALTIES: 0']
# ['SUBURB: "JOANNA" , CASUALTIES: 0']
# ['SUBURB: "JOSLIN", CASUALTIES: 2']
# ['SUBURB: "JULIA" , CASUALTIES: 0']
# ['SUBURB: "JUPITER CREEK" , CASUALTIES: 0']
# ['SUBURB: "KADINA", CASUALTIES: 1']
# ['SUBURB: "KAINTON", CASUALTIES: 0']
# ['SUBURB: "KALANGADOO" , CASUALTIES: 0']
# ['SUBURB: "KALBEEBA", CASUALTIES: 0']
# ['SUBURB: "KALDOONERA" , CASUALTIES: 0']
# ['SUBURB: "KALLORA" , CASUALTIES: 0']
# ['SUBURB: "KALTJITI" , CASUALTIES: 0']
# ['SUBURB: "KANAGARILLA" , CASUALTIES: 0']
# ['SUBURB: "KANGARILLA", CASUALTIES: 7']
# ['SUBURB: "KANGAROO FLAT" , CASUALTIES: 0']
# ['SUBURB: "KANGAROO HEAD" , CASUALTIES: 0']
# ['SUBURB: "KANGAROO INN", CASUALTIES: 2']
# ['SUBURB: "KANMANTOO" , CASUALTIES: 0']
# ['SUBURB: "KANNI" , CASUALTIES: 0']
# ['SUBURB: "KANPI" , CASUALTIES: 0']
# ['SUBURB: "KANYAKA" , CASUALTIES: 0']
# ['SUBURB: "KAPINNIE" , CASUALTIES: 0']
# ['SUBURB: "KAPUNDA", CASUALTIES: 3']
# ['SUBURB: "KARATTA" , CASUALTIES: 0']
# ['SUBURB: "KARCULTABY" , CASUALTIES: 0']
# ['SUBURB: "KARKOO" , CASUALTIES: 0']
# ['SUBURB: "KAROONDA" , CASUALTIES: 0']
# ['SUBURB: "KARRALTA PARK" , CASUALTIES: 0']
# ['SUBURB: "KATUNGA STATION" , CASUALTIES: 0']
# ['SUBURB: "KEILIRA" , CASUALTIES: 0']
# ['SUBURB: "KEITH" , CASUALTIES: 0']
# ['SUBURB: "KELLIDIE BAY" , CASUALTIES: 0']
# ['SUBURB: "KELLY" , CASUALTIES: 0']
# ['SUBURB: "KENSINGTON " , CASUALTIES: 0']
# ['SUBURB: "KENSINGTON GARDENS", CASUALTIES: 0']
# ['SUBURB: "KENSINGTON PARK", CASUALTIES: 2']
# ['SUBURB: "KENSINGTON", CASUALTIES: 6']
# ['SUBURB: "KENT TOWN", CASUALTIES: 19']
# ['SUBURB: "KENTON VALLEY" , CASUALTIES: 0']
# ['SUBURB: "KEPA" , CASUALTIES: 0']
# ['SUBURB: "KEPPOCH", CASUALTIES: 1']
# ['SUBURB: "KERSBROOK", CASUALTIES: 1']
# ['SUBURB: "KESWICK TERMINAL", CASUALTIES: 1']
# ['SUBURB: "KESWICK", CASUALTIES: 1']
# ['SUBURB: "KEYNETON" , CASUALTIES: 0']
# ['SUBURB: "KI KI" , CASUALTIES: 0']
# ['SUBURB: "KIANA" , CASUALTIES: 0']
# ['SUBURB: "KIDMAN PARK", CASUALTIES: 2']
# ['SUBURB: "KIELPA" , CASUALTIES: 0']
# ['SUBURB: "KILBURN", CASUALTIES: 2']
# ['SUBURB: "KILKENNY", CASUALTIES: 0']
# ['SUBURB: "KIMBA" , CASUALTIES: 0']
# ['SUBURB: "KINGS PARK", CASUALTIES: 0']
# ['SUBURB: "KINGSCOTE", CASUALTIES: 0']
# ['SUBURB: "KINGSFORD" , CASUALTIES: 0']
# ['SUBURB: "KINGSTON ON MURRAY", CASUALTIES: 1']
# ['SUBURB: "KINGSTON PARK" , CASUALTIES: 0']
# ['SUBURB: "KINGSTON SE" , CASUALTIES: 0']
# ['SUBURB: "KINGSWOOD" , CASUALTIES: 0']
# ['SUBURB: "KLEMZIG", CASUALTIES: 6']
# ['SUBURB: "KOHINOOR" , CASUALTIES: 0']
# ['SUBURB: "KOLENDO" , CASUALTIES: 0']
# ['SUBURB: "KONGAL" , CASUALTIES: 0']
# ['SUBURB: "KONGORONG", CASUALTIES: 1']
# ['SUBURB: "KOOLUNGA" , CASUALTIES: 0']
# ['SUBURB: "KOOLYWURTIE" , CASUALTIES: 0']
# ['SUBURB: "KOONAMORE", CASUALTIES: 0']
# ['SUBURB: "KOONGAWA" , CASUALTIES: 0']
# ['SUBURB: "KOONIBBA" , CASUALTIES: 0']
# ['SUBURB: "KOONOONA" , CASUALTIES: 0']
# ['SUBURB: "KOONUNGA" , CASUALTIES: 0']
# ['SUBURB: "KOORINE" , CASUALTIES: 0']
# ['SUBURB: "KOOTABERRA" , CASUALTIES: 0']
# ['SUBURB: "KOPPAMURRA" , CASUALTIES: 0']
# ['SUBURB: "KOPPIO" , CASUALTIES: 0']
# ['SUBURB: "KORUNYE", CASUALTIES: 2']
# ['SUBURB: "KRONDORF" , CASUALTIES: 0']
# ['SUBURB: "KUDLA", CASUALTIES: 2']
# ['SUBURB: "KUITPO COLONY" , CASUALTIES: 0']
# ['SUBURB: "KUITPO" , CASUALTIES: 0']
# ['SUBURB: "KULPARA", CASUALTIES: 1']
# ['SUBURB: "KURRALTA PARK", CASUALTIES: 2']
# ['SUBURB: "KYANCUTTA" , CASUALTIES: 0']
# ['SUBURB: "KYBUNGA" , CASUALTIES: 0']
# ['SUBURB: "KYBYBOLITE" , CASUALTIES: 0']
# ['SUBURB: "KYEEMA" , CASUALTIES: 0']
# ['SUBURB: "LAFFER" , CASUALTIES: 0']
# ['SUBURB: "LAKE GILLES" , CASUALTIES: 0']
# ['SUBURB: "LAKE PLAINS" , CASUALTIES: 0']
# ['SUBURB: "LAMEROO", CASUALTIES: 2']
# ['SUBURB: "LANGHORNE CREEK", CASUALTIES: 1']
# ['SUBURB: "LARGS BAY", CASUALTIES: 2']
# ['SUBURB: "LARGS NORTH", CASUALTIES: 2']
# ['SUBURB: "LAURA BAY" , CASUALTIES: 0']
# ['SUBURB: "LAURA" , CASUALTIES: 0']
# ['SUBURB: "LAURIE PARK" , CASUALTIES: 0']
# ['SUBURB: "LEABROOK", CASUALTIES: 1']
# ['SUBURB: "LEASINGHAM" , CASUALTIES: 0']
# ['SUBURB: "LEAWOOD GARDENS", CASUALTIES: 3']
# ['SUBURB: "LEIGH CREEK" , CASUALTIES: 0']
# ['SUBURB: "LEIGHTON" , CASUALTIES: 0']
# ['SUBURB: "LENSWOOD", CASUALTIES: 0']
# ['SUBURB: "LEWISTON" , CASUALTIES: 0']
# ['SUBURB: "LIGHT PASS" , CASUALTIES: 0']
# ['SUBURB: "LIGHTSVIEW", CASUALTIES: 0']
# ['SUBURB: "LINCOLN GAP" , CASUALTIES: 0']
# ['SUBURB: "LINCOLN NATIONAL PARK", CASUALTIES: 0']
# ['SUBURB: "LINDEN PARK", CASUALTIES: 1']
# ['SUBURB: "LINDLEY" , CASUALTIES: 0']
# ['SUBURB: "LINWOOD", CASUALTIES: 1']
# ['SUBURB: "LIPSON" , CASUALTIES: 0']
# ['SUBURB: "LITTLEHAMPTON", CASUALTIES: 1']
# ['SUBURB: "LOBETHAL", CASUALTIES: 0']
# ['SUBURB: "LOCHABER", CASUALTIES: 1']
# ['SUBURB: "LOCHIEL" , CASUALTIES: 0']
# ['SUBURB: "LOCK" , CASUALTIES: 0']
# ['SUBURB: "LOCKLEYS", CASUALTIES: 1']
# ['SUBURB: "LONG FLAT" , CASUALTIES: 0']
# ['SUBURB: "LONG PLAINS" , CASUALTIES: 0']
# ['SUBURB: "LONGWOOD" , CASUALTIES: 0']
# ['SUBURB: "LONSDALE", CASUALTIES: 5']
# ['SUBURB: "LOUTH BAY", CASUALTIES: 1']
# ['SUBURB: "LOVEDAY" , CASUALTIES: 0']
# ['SUBURB: "LOWAN VALE" , CASUALTIES: 0']
# ['SUBURB: "LOWBANK" , CASUALTIES: 0']
# ['SUBURB: "LOWER BROUGHTON" , CASUALTIES: 0']
# ['SUBURB: "LOWER HERMITAGE" , CASUALTIES: 0']
# ['SUBURB: "LOWER INMAN VALLEY", CASUALTIES: 2']
# ['SUBURB: "LOWER LIGHT", CASUALTIES: 1']
# ['SUBURB: "LOWER MITCHAM", CASUALTIES: 0']
# ['SUBURB: "LOXTON NORTH", CASUALTIES: 0']
# ['SUBURB: "LOXTON", CASUALTIES: 1']
# ['SUBURB: "LUCINDALE" , CASUALTIES: 0']
# ['SUBURB: "LYNDHURST" , CASUALTIES: 0']
# ['SUBURB: "LYNDOCH" , CASUALTIES: 0']
# ['SUBURB: "LYNTON", CASUALTIES: 0']
# ['SUBURB: "LYRUP", CASUALTIES: 0']
# ['SUBURB: "MAAOUPE" , CASUALTIES: 0']
# ['SUBURB: "MACCLESFIELD" , CASUALTIES: 0']
# ['SUBURB: "MACDONALD PARK" , CASUALTIES: 0']
# ['SUBURB: "MACGILLIVRAY" , CASUALTIES: 0']
# ['SUBURB: "MAGAREY" , CASUALTIES: 0']
# ['SUBURB: "MAGDALA" , CASUALTIES: 0']
# ['SUBURB: "MAGGEA" , CASUALTIES: 0']
# ['SUBURB: "MAGILL", CASUALTIES: 7']
# ['SUBURB: "MAITLAND", CASUALTIES: 1']
# ['SUBURB: "MAKIN" , CASUALTIES: 0']
# ['SUBURB: "MALLALA", CASUALTIES: 1']
# ['SUBURB: "MALTEE" , CASUALTIES: 0']
# ['SUBURB: "MALVERN", CASUALTIES: 0']
# ['SUBURB: "MAMBRAY CREEK" , CASUALTIES: 0']
# ['SUBURB: "MANNA HILL" , CASUALTIES: 0']
# ['SUBURB: "MANNANARIE", CASUALTIES: 2']
# ['SUBURB: "MANNINGHAM", CASUALTIES: 0']
# ['SUBURB: "MANNUM" , CASUALTIES: 0']
# ['SUBURB: "MANOORA" , CASUALTIES: 0']
# ['SUBURB: "MANSFIELD PARK", CASUALTIES: 0']
# ['SUBURB: "MANTUNG" , CASUALTIES: 0']
# ['SUBURB: "MARANANGA" , CASUALTIES: 0']
# ['SUBURB: "MARBLE HILL" , CASUALTIES: 0']
# ['SUBURB: "MARCOLLAT" , CASUALTIES: 0']
# ['SUBURB: "MARDEN", CASUALTIES: 16']
# ['SUBURB: "MARINO", CASUALTIES: 1']
# ['SUBURB: "MARION BAY" , CASUALTIES: 0']
# ['SUBURB: "MARION", CASUALTIES: 4']
# ['SUBURB: "MARKARANKA" , CASUALTIES: 0']
# ['SUBURB: "MARLA" , CASUALTIES: 0']
# ['SUBURB: "MARLESTON" , CASUALTIES: 0']
# ['SUBURB: "MARRABEL" , CASUALTIES: 0']
# ['SUBURB: "MARREE STATION" , CASUALTIES: 0']
# ['SUBURB: "MARREE" , CASUALTIES: 0']
# ['SUBURB: "MARRYATVILLE", CASUALTIES: 2']
# ['SUBURB: "MASLIN BEACH", CASUALTIES: 2']
# ['SUBURB: "MATTA FLAT" , CASUALTIES: 0']
# ['SUBURB: "MAUDE" , CASUALTIES: 0']
# ['SUBURB: "MAWSON LAKES", CASUALTIES: 10']
# ['SUBURB: "MAYLANDS", CASUALTIES: 14']
# ['SUBURB: "MCCALLUM" , CASUALTIES: 0']
# ['SUBURB: "MCCRACKEN", CASUALTIES: 0']
# ['SUBURB: "MCDOUALL PEAK", CASUALTIES: 1']
# ['SUBURB: "MCHARG CREEK", CASUALTIES: 2']
# ['SUBURB: "MCLAREN FLAT", CASUALTIES: 1']
# ['SUBURB: "MCLAREN VALE", CASUALTIES: 5']
# ['SUBURB: "MEADOWS", CASUALTIES: 5']
# ['SUBURB: "MEDIINDIE" , CASUALTIES: 0']
# ['SUBURB: "MEDINDIE GARDENS", CASUALTIES: 0']
# ['SUBURB: "MEDINDIE", CASUALTIES: 3']
# ['SUBURB: "MEDINIDIE" , CASUALTIES: 0']
# ['SUBURB: "MELROSE PARK", CASUALTIES: 5']
# ['SUBURB: "MELROSE" , CASUALTIES: 0']
# ['SUBURB: "MELTON STATION" , CASUALTIES: 0']
# ['SUBURB: "MENINGIE WEST" , CASUALTIES: 0']
# ['SUBURB: "MENINGIE", CASUALTIES: 2']
# ['SUBURB: "MENZIES" , CASUALTIES: 0']
# ['SUBURB: "MERGHINY" , CASUALTIES: 0']
# ['SUBURB: "MERIBAH" , CASUALTIES: 0']
# ['SUBURB: "MERRITON", CASUALTIES: 0']
# ['SUBURB: "MERTY MERTY" , CASUALTIES: 0']
# ['SUBURB: "MIDDLE BEACH" , CASUALTIES: 0']
# ['SUBURB: "MIDDLE RIVER" , CASUALTIES: 0']
# ['SUBURB: "MIDDLEBACK RANGE", CASUALTIES: 1']
# ['SUBURB: "MIDDLETON" , CASUALTIES: 0']
# ['SUBURB: "MIDGEE" , CASUALTIES: 0']
# ['SUBURB: "MIL-LEL" , CASUALTIES: 0']
# ['SUBURB: "MILANG" , CASUALTIES: 0']
# ['SUBURB: "MILE END SOUTH", CASUALTIES: 1']
# ['SUBURB: "MILE END", CASUALTIES: 6']
# ['SUBURB: "MILLBROOK", CASUALTIES: 1']
# ['SUBURB: "MILLICENT", CASUALTIES: 2']
# ['SUBURB: "MILLSWOOD", CASUALTIES: 0']
# ['SUBURB: "MILTALIE" , CASUALTIES: 0']
# ['SUBURB: "MIMILI" , CASUALTIES: 0']
# ['SUBURB: "MINBRIE" , CASUALTIES: 0']
# ['SUBURB: "MINDARIE" , CASUALTIES: 0']
# ['SUBURB: "MINGARY" , CASUALTIES: 0']
# ['SUBURB: "MINGBOOL", CASUALTIES: 1']
# ['SUBURB: "MINLATON" , CASUALTIES: 0']
# ['SUBURB: "MINNIPA" , CASUALTIES: 0']
# ['SUBURB: "MINTARO" , CASUALTIES: 0']
# ['SUBURB: "MIRANDA" , CASUALTIES: 0']
# ['SUBURB: "MITCHAM" , CASUALTIES: 0']
# ['SUBURB: "MITCHELL PARK", CASUALTIES: 5']
# ['SUBURB: "MITCHELLVILLE" , CASUALTIES: 0']
# ['SUBURB: "MOANA" , CASUALTIES: 0']
# ['SUBURB: "MOCULTA" , CASUALTIES: 0']
# ['SUBURB: "MODBURY HEIGHTS", CASUALTIES: 1']
# ['SUBURB: "MODBURY NORTH", CASUALTIES: 3']
# ['SUBURB: "MODBURY", CASUALTIES: 2']
# ['SUBURB: "MONARTO SOUTH", CASUALTIES: 3']
# ['SUBURB: "MONARTO", CASUALTIES: 0']
# ['SUBURB: "MONASH" , CASUALTIES: 0']
# ['SUBURB: "MONBULLA", CASUALTIES: 0']
# ['SUBURB: "MONTACUTE" , CASUALTIES: 0']
# ['SUBURB: "MONTARRA" , CASUALTIES: 0']
# ['SUBURB: "MONTEITH", CASUALTIES: 0']
# ['SUBURB: "MOOCKRA" , CASUALTIES: 0']
# ['SUBURB: "MOOLAWATANA" , CASUALTIES: 0']
# ['SUBURB: "MOONTA BAY", CASUALTIES: 0']
# ['SUBURB: "MOONTA MINES" , CASUALTIES: 0']
# ['SUBURB: "MOONTA" , CASUALTIES: 0']
# ['SUBURB: "MOORAK", CASUALTIES: 0']
# ['SUBURB: "MOORLANDS" , CASUALTIES: 0']
# ['SUBURB: "MOOROOK SOUTH" , CASUALTIES: 0']
# ['SUBURB: "MOOROOK" , CASUALTIES: 0']
# ['SUBURB: "MOPPA" , CASUALTIES: 0']
# ['SUBURB: "MORCHARD" , CASUALTIES: 0']
# ['SUBURB: "MORGAN" , CASUALTIES: 0']
# ['SUBURB: "MORN HILL" , CASUALTIES: 0']
# ['SUBURB: "MORPHETT VALE", CASUALTIES: 10']
# ['SUBURB: "MORPHETTVILLE", CASUALTIES: 3']
# ['SUBURB: "MORTANA" , CASUALTIES: 0']
# ['SUBURB: "MOSELEY" , CASUALTIES: 0']
# ['SUBURB: "MOSQUITO HILL", CASUALTIES: 0']
# ['SUBURB: "MOUNT BARKER JUNCTION" , CASUALTIES: 0']
# ['SUBURB: "MOUNT BARKER SPRINGS" , CASUALTIES: 0']
# ['SUBURB: "MOUNT BARKER SUMMIT" , CASUALTIES: 0']
# ['SUBURB: "MOUNT BARKER", CASUALTIES: 10']
# ['SUBURB: "MOUNT BARRY" , CASUALTIES: 0']
# ['SUBURB: "MOUNT BENSON" , CASUALTIES: 0']
# ['SUBURB: "MOUNT BRYAN EAST" , CASUALTIES: 0']
# ['SUBURB: "MOUNT BRYAN", CASUALTIES: 2']
# ['SUBURB: "MOUNT BURR" , CASUALTIES: 0']
# ['SUBURB: "MOUNT CHARLES" , CASUALTIES: 0']
# ['SUBURB: "MOUNT COMPASS", CASUALTIES: 1']
# ['SUBURB: "MOUNT CRAWFORD", CASUALTIES: 1']
# ['SUBURB: "MOUNT DRUMMOND" , CASUALTIES: 0']
# ['SUBURB: "MOUNT EBA" , CASUALTIES: 0']
# ['SUBURB: "MOUNT FALKLAND" , CASUALTIES: 0']
# ['SUBURB: "MOUNT GAMBIER", CASUALTIES: 8']
# ['SUBURB: "MOUNT GEORGE", CASUALTIES: 1']
# ['SUBURB: "MOUNT HOPE" , CASUALTIES: 0']
# ['SUBURB: "MOUNT IVE" , CASUALTIES: 0']
# ['SUBURB: "MOUNT JAGGED" , CASUALTIES: 0']
# ['SUBURB: "MOUNT LIGHT" , CASUALTIES: 0']
# ['SUBURB: "MOUNT LYNDHURST" , CASUALTIES: 0']
# ['SUBURB: "MOUNT MAGNIFICENT" , CASUALTIES: 0']
# ['SUBURB: "MOUNT MARY", CASUALTIES: 1']
# ['SUBURB: "MOUNT MCINTYRE" , CASUALTIES: 0']
# ['SUBURB: "MOUNT MCKENZIE" , CASUALTIES: 0']
# ['SUBURB: "MOUNT OBSERVATION" , CASUALTIES: 0']
# ['SUBURB: "MOUNT OSMOND" , CASUALTIES: 0']
# ['SUBURB: "MOUNT PLEASANT" , CASUALTIES: 0']
# ['SUBURB: "MOUNT SARAH" , CASUALTIES: 0']
# ['SUBURB: "MOUNT SCHANK" , CASUALTIES: 0']
# ['SUBURB: "MOUNT TORRENS", CASUALTIES: 0']
# ['SUBURB: "MOUNT WILLOUGHBY" , CASUALTIES: 0']
# ['SUBURB: "MOYHALL" , CASUALTIES: 0']
# ['SUBURB: "MUDAMUCKLA" , CASUALTIES: 0']
# ['SUBURB: "MULGUNDAWA" , CASUALTIES: 0']
# ['SUBURB: "MULLAQUANA" , CASUALTIES: 0']
# ['SUBURB: "MULOORINA" , CASUALTIES: 0']
# ['SUBURB: "MULYUNGARIE" , CASUALTIES: 0']
# ['SUBURB: "MUNDOORA" , CASUALTIES: 0']
# ['SUBURB: "MUNDOWDNA" , CASUALTIES: 0']
# ['SUBURB: "MUNDULLA WEST" , CASUALTIES: 0']
# ['SUBURB: "MUNDULLA" , CASUALTIES: 0']
# ['SUBURB: "MUNNO PARA DOWNS", CASUALTIES: 2']
# ['SUBURB: "MUNNO PARA WEST", CASUALTIES: 1']
# ['SUBURB: "MUNNO PARA", CASUALTIES: 10']
# ['SUBURB: "MURBKO" , CASUALTIES: 0']
# ['SUBURB: "MURDINGA" , CASUALTIES: 0']
# ['SUBURB: "MURPUTJA" , CASUALTIES: 0']
# ['SUBURB: "MURRAY BRIDGE EAST", CASUALTIES: 1']
# ['SUBURB: "MURRAY BRIDGE NORTH", CASUALTIES: 1']
# ['SUBURB: "MURRAY BRIDGE SOUTH", CASUALTIES: 0']
# ['SUBURB: "MURRAY BRIDGE", CASUALTIES: 7']
# ['SUBURB: "MURTHO" , CASUALTIES: 0']
# ['SUBURB: "MUSTON" , CASUALTIES: 0']
# ['SUBURB: "MYLOR" , CASUALTIES: 0']
# ['SUBURB: "MYPOLONGA" , CASUALTIES: 0']
# ['SUBURB: "MYPONGA BEACH" , CASUALTIES: 0']
# ['SUBURB: "MYPONGA", CASUALTIES: 4']
# ['SUBURB: "MYRTLE BANK", CASUALTIES: 0']
# ['SUBURB: "MYRTLE SPRINGS" , CASUALTIES: 0']
# ['SUBURB: "NACKARA" , CASUALTIES: 0']
# ['SUBURB: "NADIA" , CASUALTIES: 0']
# ['SUBURB: "NAIDIA" , CASUALTIES: 0']
# ['SUBURB: "NAILSWORTH", CASUALTIES: 2']
# ['SUBURB: "NAIN" , CASUALTIES: 0']
# ['SUBURB: "NAIRNE", CASUALTIES: 2']
# ['SUBURB: "NALYAPPA", CASUALTIES: 1']
# ['SUBURB: "NANGKITA", CASUALTIES: 2']
# ['SUBURB: "NANGWARRY", CASUALTIES: 1']
# ['SUBURB: "NANTAWARRA" , CASUALTIES: 0']
# ['SUBURB: "NAPPERBY" , CASUALTIES: 0']
# ['SUBURB: "NARACOORTE", CASUALTIES: 2']
# ['SUBURB: "NARRIDY" , CASUALTIES: 0']
# ['SUBURB: "NARRUNG" , CASUALTIES: 0']
# ['SUBURB: "NATURI" , CASUALTIES: 0']
# ['SUBURB: "NEALES FLAT" , CASUALTIES: 0']
# ['SUBURB: "NECTAR BROOK" , CASUALTIES: 0']
# ['SUBURB: "NELSHABY" , CASUALTIES: 0']
# ['SUBURB: "NEPABUNNA", CASUALTIES: 1']
# ['SUBURB: "NEPEAN BAY" , CASUALTIES: 0']
# ['SUBURB: "NETHERBY" , CASUALTIES: 0']
# ['SUBURB: "NETHERTON" , CASUALTIES: 0']
# ['SUBURB: "NETLEY", CASUALTIES: 1']
# ['SUBURB: "NEW PORT", CASUALTIES: 0']
# ['SUBURB: "NEW RESIDENCE" , CASUALTIES: 0']
# ['SUBURB: "NEW TOWN" , CASUALTIES: 0']
# ['SUBURB: "NEW WELL" , CASUALTIES: 0']
# ['SUBURB: "NEWLAND" , CASUALTIES: 0']
# ['SUBURB: "NEWTON", CASUALTIES: 1']
# ['SUBURB: "NGAPALA" , CASUALTIES: 0']
# ['SUBURB: "NGARKAT" , CASUALTIES: 0']
# ['SUBURB: "NILDOTTIE", CASUALTIES: 2']
# ['SUBURB: "NILPENA" , CASUALTIES: 0']
# ['SUBURB: "NILPINNA STATION" , CASUALTIES: 0']
# ['SUBURB: "NINNES" , CASUALTIES: 0']
# ['SUBURB: "NOARLUNGA CENTRE", CASUALTIES: 1']
# ['SUBURB: "NOARLUNGA DOWNS", CASUALTIES: 2']
# ['SUBURB: "NONNING" , CASUALTIES: 0']
# ['SUBURB: "NORA CREINA" , CASUALTIES: 0']
# ['SUBURB: "NORMANVILLE", CASUALTIES: 1']
# ['SUBURB: "NORTH ADELAIDE", CASUALTIES: 13']
# ['SUBURB: "NORTH BRIGHTON", CASUALTIES: 0']
# ['SUBURB: "NORTH HAVEN" , CASUALTIES: 0']
# ['SUBURB: "NORTH MOOLOOLOO" , CASUALTIES: 0']
# ['SUBURB: "NORTH MOONTA", CASUALTIES: 0']
# ['SUBURB: "NORTH PLYMPTON", CASUALTIES: 1']
# ['SUBURB: "NORTH SHIELDS" , CASUALTIES: 0']
# ['SUBURB: "NORTH YELTA" , CASUALTIES: 0']
# ['SUBURB: "NORTHERN HEIGHTS" , CASUALTIES: 0']
# ['SUBURB: "NORTHFIELD", CASUALTIES: 2']
# ['SUBURB: "NORTHGATE", CASUALTIES: 0']
# ['SUBURB: "NORTON SUMMIT", CASUALTIES: 0']
# ['SUBURB: "NORWOOD", CASUALTIES: 17']
# ['SUBURB: "NOVAR GARDENS", CASUALTIES: 2']
# ['SUBURB: "NULLARBOR" , CASUALTIES: 0']
# ['SUBURB: "NUNJIKOMPITA" , CASUALTIES: 0']
# ['SUBURB: "NURIOOTPA", CASUALTIES: 1']
# ['SUBURB: "NURRAGI" , CASUALTIES: 0']
# ['SUBURB: "O\'HALLORAN HILL", CASUALTIES: 3']
# ['SUBURB: "O\'SULLIVAN BEACH", CASUALTIES: 2']
# ['SUBURB: "OAKBANK" , CASUALTIES: 0']
# ['SUBURB: "OAKDEN HILLS", CASUALTIES: 1']
# ['SUBURB: "OAKDEN", CASUALTIES: 4']
# ['SUBURB: "OAKLANDS PARK", CASUALTIES: 3']
# ['SUBURB: "OB FLAT" , CASUALTIES: 0']
# ['SUBURB: "OLARY", CASUALTIES: 0']
# ['SUBURB: "OLD CALPERUM" , CASUALTIES: 0']
# ['SUBURB: "OLD NOARLUNGA", CASUALTIES: 2']
# ['SUBURB: "OLD REYNELLA", CASUALTIES: 1']
# ['SUBURB: "OLYMPIC DAM", CASUALTIES: 1']
# ['SUBURB: "ONE TREE HILL", CASUALTIES: 2']
# ['SUBURB: "ONKAPARINGA HILLS", CASUALTIES: 7']
# ['SUBURB: "OODLA WIRRA" , CASUALTIES: 0']
# ['SUBURB: "OODNADATTA" , CASUALTIES: 0']
# ['SUBURB: "ORROROO" , CASUALTIES: 0']
# ['SUBURB: "OSBORNE", CASUALTIES: 3']
# ['SUBURB: "OTTOWAY", CASUALTIES: 1']
# ['SUBURB: "OULINA" , CASUALTIES: 0']
# ['SUBURB: "OUTER HARBOR" , CASUALTIES: 0']
# ['SUBURB: "OVERLAND CORNER", CASUALTIES: 2']
# ['SUBURB: "OVINGHAM", CASUALTIES: 1']
# ['SUBURB: "OWEN" , CASUALTIES: 0']
# ['SUBURB: "PADTHAWAY", CASUALTIES: 0']
# ['SUBURB: "PAECHTOWN", CASUALTIES: 0']
# ['SUBURB: "PAGES FLAT" , CASUALTIES: 0']
# ['SUBURB: "PAISLEY" , CASUALTIES: 0']
# ['SUBURB: "PALLAMANA" , CASUALTIES: 0']
# ['SUBURB: "PALMER", CASUALTIES: 2']
# ['SUBURB: "PANDIE PANDIE" , CASUALTIES: 0']
# ['SUBURB: "PANDURRA" , CASUALTIES: 0']
# ['SUBURB: "PANITYA" , CASUALTIES: 0']
# ['SUBURB: "PANORAMA", CASUALTIES: 0']
# ['SUBURB: "PARA HILLS WEST", CASUALTIES: 9']
# ['SUBURB: "PARA HILLS", CASUALTIES: 4']
# ['SUBURB: "PARA VISTA", CASUALTIES: 2']
# ['SUBURB: "PARACOMBE", CASUALTIES: 3']
# ['SUBURB: "PARADISE", CASUALTIES: 4']
# ['SUBURB: "PARAFIELD GARDENS", CASUALTIES: 7']
# ['SUBURB: "PARAFIELD", CASUALTIES: 1']
# ['SUBURB: "PARALOWIE", CASUALTIES: 4']
# ['SUBURB: "PARAMATTA" , CASUALTIES: 0']
# ['SUBURB: "PARAWA" , CASUALTIES: 0']
# ['SUBURB: "PARILLA", CASUALTIES: 0']
# ['SUBURB: "PARINGA" , CASUALTIES: 0']
# ['SUBURB: "PARIS CREEK", CASUALTIES: 1']
# ['SUBURB: "PARK HOLME", CASUALTIES: 4']
# ['SUBURB: "PARKSIDE", CASUALTIES: 5']
# ['SUBURB: "PARNAROO" , CASUALTIES: 0']
# ['SUBURB: "PARNDANA" , CASUALTIES: 0']
# ['SUBURB: "PARRAKIE" , CASUALTIES: 0']
# ['SUBURB: "PARUNA" , CASUALTIES: 0']
# ['SUBURB: "PASADENA", CASUALTIES: 2']
# ['SUBURB: "PASKEVILLE" , CASUALTIES: 0']
# ['SUBURB: "PATA" , CASUALTIES: 0']
# ['SUBURB: "PAYNEHAM SOUTH", CASUALTIES: 4']
# ['SUBURB: "PAYNEHAM", CASUALTIES: 17']
# ['SUBURB: "PEAKE" , CASUALTIES: 0']
# ['SUBURB: "PEARLAH" , CASUALTIES: 0']
# ['SUBURB: "PEEBINGA" , CASUALTIES: 0']
# ['SUBURB: "PEKINA" , CASUALTIES: 0']
# ['SUBURB: "PELICAN LAGOON" , CASUALTIES: 0']
# ['SUBURB: "PENFIELD GARDENS", CASUALTIES: 3']
# ['SUBURB: "PENFIELD", CASUALTIES: 6']
# ['SUBURB: "PENNESHAW", CASUALTIES: 1']
# ['SUBURB: "PENNINGTON", CASUALTIES: 1']
# ['SUBURB: "PENOLA" , CASUALTIES: 0']
# ['SUBURB: "PENONG", CASUALTIES: 1']
# ['SUBURB: "PENRICE", CASUALTIES: 1']
# ['SUBURB: "PENWORTHAM" , CASUALTIES: 0']
# ['SUBURB: "PERLUBIE" , CASUALTIES: 0']
# ['SUBURB: "PETERBOROUGH" , CASUALTIES: 0']
# ['SUBURB: "PETERHEAD" , CASUALTIES: 0']
# ['SUBURB: "PETERSVILLE" , CASUALTIES: 0']
# ['SUBURB: "PETHERICK" , CASUALTIES: 0']
# ['SUBURB: "PETINA" , CASUALTIES: 0']
# ['SUBURB: "PETWOOD" , CASUALTIES: 0']
# ['SUBURB: "PEWSEY VALE", CASUALTIES: 4']
# ['SUBURB: "PICCADILLY" , CASUALTIES: 0']
# ['SUBURB: "PIKE RIVER", CASUALTIES: 0']
# ['SUBURB: "PIMBA" , CASUALTIES: 0']
# ['SUBURB: "PINE CREEK STATION" , CASUALTIES: 0']
# ['SUBURB: "PINE HILL" , CASUALTIES: 0']
# ['SUBURB: "PINE POINT" , CASUALTIES: 0']
# ['SUBURB: "PINERY" , CASUALTIES: 0']
# ['SUBURB: "PINKERTON PLAINS" , CASUALTIES: 0']
# ['SUBURB: "PINKS BEACH" , CASUALTIES: 0']
# ['SUBURB: "PINNAROO", CASUALTIES: 2']
# ['SUBURB: "PIPALYATJARA", CASUALTIES: 3']
# ['SUBURB: "PIRIE EAST" , CASUALTIES: 0']
# ['SUBURB: "PLEASANT PARK" , CASUALTIES: 0']
# ['SUBURB: "PLYMPTON PARK" , CASUALTIES: 0']
# ['SUBURB: "PLYMPTON", CASUALTIES: 9']
# ['SUBURB: "POINT BOSTON" , CASUALTIES: 0']
# ['SUBURB: "POINT LOWLY" , CASUALTIES: 0']
# ['SUBURB: "POINT PASS", CASUALTIES: 0']
# ['SUBURB: "POINT PEARCE" , CASUALTIES: 0']
# ['SUBURB: "POINT SOUTTAR" , CASUALTIES: 0']
# ['SUBURB: "POINT STURT", CASUALTIES: 1']
# ['SUBURB: "POINT TURTON" , CASUALTIES: 0']
# ['SUBURB: "POLDA" , CASUALTIES: 0']
# ['SUBURB: "POLISH HILL RIVER" , CASUALTIES: 0']
# ['SUBURB: "POLTALLOCH", CASUALTIES: 1']
# ['SUBURB: "POMPOOTA" , CASUALTIES: 0']
# ['SUBURB: "PONDE" , CASUALTIES: 0']
# ['SUBURB: "POOCHERA" , CASUALTIES: 0']
# ['SUBURB: "POOGINAGORIC", CASUALTIES: 1']
# ['SUBURB: "POOGINOOK" , CASUALTIES: 0']
# ['SUBURB: "POORAKA", CASUALTIES: 2']
# ['SUBURB: "PORT ADELAIDE", CASUALTIES: 4']
# ['SUBURB: "PORT ARTHUR" , CASUALTIES: 0']
# ['SUBURB: "PORT AUGUSTA WEST", CASUALTIES: 2']
# ['SUBURB: "PORT AUGUSTA", CASUALTIES: 3']
# ['SUBURB: "PORT BONYTHON" , CASUALTIES: 0']
# ['SUBURB: "PORT BROUGHTON" , CASUALTIES: 0']
# ['SUBURB: "PORT DAVIS" , CASUALTIES: 0']
# ['SUBURB: "PORT ELLIOT", CASUALTIES: 1']
# ['SUBURB: "PORT GAWLER" , CASUALTIES: 0']
# ['SUBURB: "PORT GERMEIN" , CASUALTIES: 0']
# ['SUBURB: "PORT HUGHES" , CASUALTIES: 0']
# ['SUBURB: "PORT JULIA" , CASUALTIES: 0']
# ['SUBURB: "PORT KENNY" , CASUALTIES: 0']
# ['SUBURB: "PORT LINCOLN", CASUALTIES: 2']
# ['SUBURB: "PORT MACDONNELL", CASUALTIES: 1']
# ['SUBURB: "PORT MOOROWIE" , CASUALTIES: 0']
# ['SUBURB: "PORT NEILL" , CASUALTIES: 0']
# ['SUBURB: "PORT NOARLUNGA SOUTH", CASUALTIES: 1']
# ['SUBURB: "PORT NOARLUNGA", CASUALTIES: 4']
# ['SUBURB: "PORT PATERSON" , CASUALTIES: 0']
# ['SUBURB: "PORT PIRIE SOUTH", CASUALTIES: 2']
# ['SUBURB: "PORT PIRIE WEST", CASUALTIES: 0']
# ['SUBURB: "PORT PIRIE", CASUALTIES: 0']
# ['SUBURB: "PORT RICKABY", CASUALTIES: 1']
# ['SUBURB: "PORT VICTORIA" , CASUALTIES: 0']
# ['SUBURB: "PORT VINCENT" , CASUALTIES: 0']
# ['SUBURB: "PORT WAKEFIELD", CASUALTIES: 1']
# ['SUBURB: "PORT WILLUNGA", CASUALTIES: 0']
# ['SUBURB: "PORTER LAGOON", CASUALTIES: 1']
# ['SUBURB: "PRICE" , CASUALTIES: 0']
# ['SUBURB: "PROSPECT HILL" , CASUALTIES: 0']
# ['SUBURB: "PROSPECT", CASUALTIES: 14']
# ['SUBURB: "PUKATJA", CASUALTIES: 3']
# ['SUBURB: "PUNTABIE" , CASUALTIES: 0']
# ['SUBURB: "PUNYELROO" , CASUALTIES: 0']
# ['SUBURB: "PURNONG", CASUALTIES: 1']
# ['SUBURB: "PURPLE DOWNS" , CASUALTIES: 0']
# ['SUBURB: "PUTTAPA" , CASUALTIES: 0']
# ['SUBURB: "PYAP WEST" , CASUALTIES: 0']
# ['SUBURB: "PYAP" , CASUALTIES: 0']
# ['SUBURB: "PYGERY" , CASUALTIES: 0']
# ['SUBURB: "QUALCO" , CASUALTIES: 0']
# ['SUBURB: "QUEENSTOWN", CASUALTIES: 0']
# ['SUBURB: "QUORN" , CASUALTIES: 0']
# ['SUBURB: "RACECOURSE BAY" , CASUALTIES: 0']
# ['SUBURB: "RAMCO" , CASUALTIES: 0']
# ['SUBURB: "RAMSAY" , CASUALTIES: 0']
# ['SUBURB: "RAPID BAY" , CASUALTIES: 0']
# ['SUBURB: "RED CREEK" , CASUALTIES: 0']
# ['SUBURB: "REDBANKS" , CASUALTIES: 0']
# ['SUBURB: "REDHILL" , CASUALTIES: 0']
# ['SUBURB: "REDWOOD PARK", CASUALTIES: 2']
# ['SUBURB: "REEDY CREEK" , CASUALTIES: 0']
# ['SUBURB: "REEVES PLAINS", CASUALTIES: 0']
# ['SUBURB: "REGENCY  PARK" , CASUALTIES: 0']
# ['SUBURB: "REGENCY PARK", CASUALTIES: 3']
# ['SUBURB: "REID" , CASUALTIES: 0']
# ['SUBURB: "RENDELSHAM" , CASUALTIES: 0']
# ['SUBURB: "RENMARK NORTH", CASUALTIES: 1']
# ['SUBURB: "RENMARK SOUTH", CASUALTIES: 1']
# ['SUBURB: "RENMARK WEST" , CASUALTIES: 0']
# ['SUBURB: "RENMARK", CASUALTIES: 0']
# ['SUBURB: "RENOWN PARK", CASUALTIES: 2']
# ['SUBURB: "REYNELLA EAST" , CASUALTIES: 0']
# ['SUBURB: "REYNELLA", CASUALTIES: 1']
# ['SUBURB: "RHYNIE" , CASUALTIES: 0']
# ['SUBURB: "RICHMOND", CASUALTIES: 1']
# ['SUBURB: "RIDGEHAVEN", CASUALTIES: 0']
# ['SUBURB: "RIDLEYTON", CASUALTIES: 3']
# ['SUBURB: "RISDON PARK SOUTH", CASUALTIES: 1']
# ['SUBURB: "RISDON PARK", CASUALTIES: 1']
# ['SUBURB: "RIVERGLADES", CASUALTIES: 1']
# ['SUBURB: "RIVERGLEN" , CASUALTIES: 0']
# ['SUBURB: "RIVERTON" , CASUALTIES: 0']
# ['SUBURB: "ROBE" , CASUALTIES: 0']
# ['SUBURB: "ROBERTSTOWN" , CASUALTIES: 0']
# ['SUBURB: "ROCHESTER" , CASUALTIES: 0']
# ['SUBURB: "ROCKLEIGH" , CASUALTIES: 0']
# ['SUBURB: "ROCKY CAMP", CASUALTIES: 2']
# ['SUBURB: "ROCKY GULLY", CASUALTIES: 1']
# ['SUBURB: "ROSE PARK", CASUALTIES: 0']
# ['SUBURB: "ROSEDALE" , CASUALTIES: 0']
# ['SUBURB: "ROSETOWN" , CASUALTIES: 0']
# ['SUBURB: "ROSEWATER", CASUALTIES: 1']
# ['SUBURB: "ROSEWORTHY", CASUALTIES: 6']
# ['SUBURB: "ROSSLYN PARK", CASUALTIES: 1']
# ['SUBURB: "ROSTREVOR", CASUALTIES: 1']
# ['SUBURB: "ROWLAND FLAT" , CASUALTIES: 0']
# ['SUBURB: "ROXBY DOWNS STATION" , CASUALTIES: 0']
# ['SUBURB: "ROXBY DOWNS", CASUALTIES: 2']
# ['SUBURB: "ROYAL PARK", CASUALTIES: 1']
# ['SUBURB: "ROYSTON PARK", CASUALTIES: 13']
# ['SUBURB: "RUDALL" , CASUALTIES: 0']
# ['SUBURB: "SADDLEWORTH" , CASUALTIES: 0']
# ['SUBURB: "SAINTS" , CASUALTIES: 0']
# ['SUBURB: "SALEM" , CASUALTIES: 0']
# ['SUBURB: "SALISBURY DOWNS", CASUALTIES: 11']
# ['SUBURB: "SALISBURY EAST", CASUALTIES: 16']
# ['SUBURB: "SALISBURY HEIGHTS", CASUALTIES: 1']
# ['SUBURB: "SALISBURY NORTH", CASUALTIES: 9']
# ['SUBURB: "SALISBURY PARK", CASUALTIES: 0']
# ['SUBURB: "SALISBURY PLAIN", CASUALTIES: 10']
# ['SUBURB: "SALISBURY SOUTH", CASUALTIES: 11']
# ['SUBURB: "SALISBURY", CASUALTIES: 18']
# ['SUBURB: "SALSBURY EAST" , CASUALTIES: 0']
# ['SUBURB: "SALT CREEK" , CASUALTIES: 0']
# ['SUBURB: "SALTER SPRINGS" , CASUALTIES: 0']
# ['SUBURB: "SALTIA" , CASUALTIES: 0']
# ['SUBURB: "SAMPSON FLAT", CASUALTIES: 1']
# ['SUBURB: "SANDALWOOD" , CASUALTIES: 0']
# ['SUBURB: "SANDERGROVE" , CASUALTIES: 0']
# ['SUBURB: "SANDERSTON" , CASUALTIES: 0']
# ['SUBURB: "SANDILANDS" , CASUALTIES: 0']
# ['SUBURB: "SANDLETON" , CASUALTIES: 0']
# ['SUBURB: "SANDY CREEK" , CASUALTIES: 0']
# ['SUBURB: "SANDY GROVE" , CASUALTIES: 0']
# ['SUBURB: "SCEALE BAY" , CASUALTIES: 0']
# ['SUBURB: "SCOTT CREEK" , CASUALTIES: 0']
# ['SUBURB: "SEACLIFF PARK", CASUALTIES: 0']
# ['SUBURB: "SEACLIFF", CASUALTIES: 0']
# ['SUBURB: "SEACOMBE GARDENS" , CASUALTIES: 0']
# ['SUBURB: "SEACOMBE HEIGHTS", CASUALTIES: 0']
# ['SUBURB: "SEAFORD HEIGHTS" , CASUALTIES: 0']
# ['SUBURB: "SEAFORD MEADOWS", CASUALTIES: 4']
# ['SUBURB: "SEAFORD RISE", CASUALTIES: 3']
# ['SUBURB: "SEAFORD", CASUALTIES: 2']
# ['SUBURB: "SEATON", CASUALTIES: 8']
# ['SUBURB: "SEAVIEW DOWNS" , CASUALTIES: 0']
# ['SUBURB: "SEBASTOPOL" , CASUALTIES: 0']
# ['SUBURB: "SECOND VALLEY" , CASUALTIES: 0']
# ['SUBURB: "SEDAN", CASUALTIES: 4']
# ['SUBURB: "SEDDON", CASUALTIES: 0']
# ['SUBURB: "SEFTON PARK", CASUALTIES: 0']
# ['SUBURB: "SELLICKS BEACH", CASUALTIES: 0']
# ['SUBURB: "SELLICKS HILL", CASUALTIES: 1']
# ['SUBURB: "SEMAPHORE PARK", CASUALTIES: 2']
# ['SUBURB: "SEMAPHORE SOUTH", CASUALTIES: 5']
# ['SUBURB: "SEMAPHORE", CASUALTIES: 1']
# ['SUBURB: "SENIOR" , CASUALTIES: 0']
# ['SUBURB: "SEPPELTSFIELD", CASUALTIES: 0']
# ['SUBURB: "SEVENHILL" , CASUALTIES: 0']
# ['SUBURB: "SHAUGH" , CASUALTIES: 0']
# ['SUBURB: "SHEA - OAK LOG" , CASUALTIES: 0']
# ['SUBURB: "SHEA-OAK LOG" , CASUALTIES: 0']
# ['SUBURB: "SHEIDOW PARK", CASUALTIES: 1']
# ['SUBURB: "SHERINGA" , CASUALTIES: 0']
# ['SUBURB: "SHERLOCK" , CASUALTIES: 0']
# ['SUBURB: "SHERWOOD" , CASUALTIES: 0']
# ['SUBURB: "SHORT" , CASUALTIES: 0']
# ['SUBURB: "SILVERTON" , CASUALTIES: 0']
# ['SUBURB: "SIMPSON DESERT" , CASUALTIES: 0']
# ['SUBURB: "SKYE" , CASUALTIES: 0']
# ['SUBURB: "SLEAFORD" , CASUALTIES: 0']
# ['SUBURB: "SMITHFIELD PLAINS", CASUALTIES: 2']
# ['SUBURB: "SMITHFIELD", CASUALTIES: 6']
# ['SUBURB: "SMOKY BAY" , CASUALTIES: 0']
# ['SUBURB: "SNOWTOWN", CASUALTIES: 1']
# ['SUBURB: "SOLOMON" , CASUALTIES: 0']
# ['SUBURB: "SOLOMONTOWN", CASUALTIES: 0']
# ['SUBURB: "SOMERTON PARK", CASUALTIES: 3']
# ['SUBURB: "SOUTH BRIGHTON", CASUALTIES: 1']
# ['SUBURB: "SOUTH HUMMOCKS" , CASUALTIES: 0']
# ['SUBURB: "SOUTH KILKERRAN" , CASUALTIES: 0']
# ['SUBURB: "SOUTH PLYMPTON", CASUALTIES: 8']
# ['SUBURB: "SOUTHEND", CASUALTIES: 1']
# ['SUBURB: "SPALDING", CASUALTIES: 0']
# ['SUBURB: "SPENCE" , CASUALTIES: 0']
# ['SUBURB: "SPRING FARM" , CASUALTIES: 0']
# ['SUBURB: "SPRING GULLY" , CASUALTIES: 0']
# ['SUBURB: "SPRINGFIELD" , CASUALTIES: 0']
# ['SUBURB: "SPRINGTON" , CASUALTIES: 0']
# ['SUBURB: "SQUARE MILE" , CASUALTIES: 0']
# ['SUBURB: "ST AGNES", CASUALTIES: 2']
# ['SUBURB: "ST CLAIR", CASUALTIES: 3']
# ['SUBURB: "ST GEORGES", CASUALTIES: 1']
# ['SUBURB: "ST IVES" , CASUALTIES: 0']
# ['SUBURB: "ST JOHNS" , CASUALTIES: 0']
# ['SUBURB: "ST KILDA" , CASUALTIES: 0']
# ['SUBURB: "ST MARYS", CASUALTIES: 6']
# ['SUBURB: "ST MORRIS", CASUALTIES: 2']
# ['SUBURB: "ST PETERS", CASUALTIES: 7']
# ['SUBURB: "STANLEY FLAT" , CASUALTIES: 0']
# ['SUBURB: "STANLEY" , CASUALTIES: 0']
# ['SUBURB: "STANSBURY" , CASUALTIES: 0']
# ['SUBURB: "STEINFELD" , CASUALTIES: 0']
# ['SUBURB: "STEPNEY", CASUALTIES: 15']
# ['SUBURB: "STEWART RANGE" , CASUALTIES: 0']
# ['SUBURB: "STIRLING NORTH", CASUALTIES: 3']
# ['SUBURB: "STIRLING", CASUALTIES: 1']
# ['SUBURB: "STOCKPORT", CASUALTIES: 1']
# ['SUBURB: "STOCKWELL" , CASUALTIES: 0']
# ['SUBURB: "STOCKYARD CREEK" , CASUALTIES: 0']
# ['SUBURB: "STOCKYARD PLAIN" , CASUALTIES: 0']
# ['SUBURB: "STOKES BAY" , CASUALTIES: 0']
# ['SUBURB: "STONE WELL" , CASUALTIES: 0']
# ['SUBURB: "STONYFELL" , CASUALTIES: 0']
# ['SUBURB: "STRATHALBYN" , CASUALTIES: 0']
# ['SUBURB: "STREAKY BAY", CASUALTIES: 0']
# ['SUBURB: "STRUAN", CASUALTIES: 0']
# ['SUBURB: "STUART" , CASUALTIES: 0']
# ['SUBURB: "STUARTS CREEK" , CASUALTIES: 0']
# ['SUBURB: "STURT VALE" , CASUALTIES: 0']
# ['SUBURB: "STURT", CASUALTIES: 6']
# ['SUBURB: "SULTANA POINT" , CASUALTIES: 0']
# ['SUBURB: "SUMMERTON" , CASUALTIES: 0']
# ['SUBURB: "SUMMERTOWN", CASUALTIES: 4']
# ['SUBURB: "SUNLANDS" , CASUALTIES: 0']
# ['SUBURB: "SUNNYBRAE" , CASUALTIES: 0']
# ['SUBURB: "SUNNYDALE" , CASUALTIES: 0']
# ['SUBURB: "SUNNYVALE" , CASUALTIES: 0']
# ['SUBURB: "SURREY DOWNS", CASUALTIES: 0']
# ['SUBURB: "SUTHERLANDS" , CASUALTIES: 0']
# ['SUBURB: "SUTTONTOWN", CASUALTIES: 3']
# ['SUBURB: "SWAN REACH", CASUALTIES: 2']
# ['SUBURB: "SWANPORT" , CASUALTIES: 0']
# ['SUBURB: "SWEDE FLAT" , CASUALTIES: 0']
# ['SUBURB: "TAILEM BEND", CASUALTIES: 1']
# ['SUBURB: "TALDRA" , CASUALTIES: 0']
# ['SUBURB: "TALIA" , CASUALTIES: 0']
# ['SUBURB: "TANTANOOLA", CASUALTIES: 0']
# ['SUBURB: "TANUNDA", CASUALTIES: 1']
# ['SUBURB: "TAPEROO", CASUALTIES: 2']
# ['SUBURB: "TAPLAN" , CASUALTIES: 0']
# ['SUBURB: "TARATAP" , CASUALTIES: 0']
# ['SUBURB: "TARCOOLA" , CASUALTIES: 0']
# ['SUBURB: "TARLEE" , CASUALTIES: 0']
# ['SUBURB: "TARPEENA" , CASUALTIES: 0']
# ['SUBURB: "TATACHILLA", CASUALTIES: 1']
# ['SUBURB: "TAYLORVILLE" , CASUALTIES: 0']
# ['SUBURB: "TEA TREE GULLY", CASUALTIES: 1']
# ['SUBURB: "TEAL FLAT" , CASUALTIES: 0']
# ['SUBURB: "TELOWIE", CASUALTIES: 0']
# ['SUBURB: "TEMPLERS" , CASUALTIES: 0']
# ['SUBURB: "TENNYSON", CASUALTIES: 1']
# ['SUBURB: "TEPKO" , CASUALTIES: 0']
# ['SUBURB: "TERINGIE" , CASUALTIES: 0']
# ['SUBURB: "TEROWIE" , CASUALTIES: 0']
# ['SUBURB: "THE GAP" , CASUALTIES: 0']
# ['SUBURB: "THE PINES", CASUALTIES: 1']
# ['SUBURB: "THE RANGE" , CASUALTIES: 0']
# ['SUBURB: "THEBARTON", CASUALTIES: 1']
# ['SUBURB: "THEVENARD" , CASUALTIES: 0']
# ['SUBURB: "THOMAS PLAIN" , CASUALTIES: 0']
# ['SUBURB: "THOMPSON BEACH" , CASUALTIES: 0']
# ['SUBURB: "THORNGATE", CASUALTIES: 1']
# ['SUBURB: "THORNLEA" , CASUALTIES: 0']
# ['SUBURB: "THRINGTON" , CASUALTIES: 0']
# ['SUBURB: "TIATUKIA", CASUALTIES: 2']
# ['SUBURB: "TICKERA" , CASUALTIES: 0']
# ['SUBURB: "TIKALINA" , CASUALTIES: 0']
# ['SUBURB: "TILLEY SWAMP" , CASUALTIES: 0']
# ['SUBURB: "TINTINARA", CASUALTIES: 0']
# ['SUBURB: "TODMORDEN", CASUALTIES: 1']
# ['SUBURB: "TONSLEY" , CASUALTIES: 0']
# ['SUBURB: "TOOLIGIE" , CASUALTIES: 0']
# ['SUBURB: "TOOPERANG", CASUALTIES: 1']
# ['SUBURB: "TOORA" , CASUALTIES: 0']
# ['SUBURB: "TOORAK GARDENS", CASUALTIES: 0']
# ['SUBURB: "TORRENS PARK", CASUALTIES: 4']
# ['SUBURB: "TORRENS VALE" , CASUALTIES: 0']
# ['SUBURB: "TORRENSVILLE", CASUALTIES: 5']
# ['SUBURB: "TOTHILL CREEK", CASUALTIES: 1']
# ['SUBURB: "TOTNESS", CASUALTIES: 4']
# ['SUBURB: "TOWITTA" , CASUALTIES: 0']
# ['SUBURB: "TRANMERE", CASUALTIES: 8']
# ['SUBURB: "TRIHI" , CASUALTIES: 0']
# ['SUBURB: "TRINITY GARDENS", CASUALTIES: 4']
# ['SUBURB: "TROTT PARK", CASUALTIES: 1']
# ['SUBURB: "TRURO", CASUALTIES: 0']
# ['SUBURB: "TULKA" , CASUALTIES: 0']
# ['SUBURB: "TUMBY BAY", CASUALTIES: 0']
# ['SUBURB: "TUNGKILLO", CASUALTIES: 0']
# ['SUBURB: "TUNKALILLA" , CASUALTIES: 0']
# ['SUBURB: "TUSMORE", CASUALTIES: 0']
# ['SUBURB: "TWO WELLS", CASUALTIES: 2']
# ['SUBURB: "UCOLTA" , CASUALTIES: 0']
# ['SUBURB: "ULEYBURY", CASUALTIES: 0']
# ['SUBURB: "ULOOLOO" , CASUALTIES: 0']
# ['SUBURB: "ULYERRA" , CASUALTIES: 0']
# ['SUBURB: "UMUWA", CASUALTIES: 0']
# ['SUBURB: "UNDALYA", CASUALTIES: 3']
# ['SUBURB: "UNDERDALE", CASUALTIES: 1']
# ['SUBURB: "UNGARRA" , CASUALTIES: 0']
# ['SUBURB: "UNLEY PARK", CASUALTIES: 0']
# ['SUBURB: "UNLEY", CASUALTIES: 2']
# ['SUBURB: "UPALINNA" , CASUALTIES: 0']
# ['SUBURB: "UPPER HERMITAGE", CASUALTIES: 0']
# ['SUBURB: "UPPER STURT" , CASUALTIES: 0']
# ['SUBURB: "URAIDLA" , CASUALTIES: 0']
# ['SUBURB: "URANIA" , CASUALTIES: 0']
# ['SUBURB: "URRBRAE", CASUALTIES: 2']
# ['SUBURB: "UWORRA" , CASUALTIES: 0']
# ['SUBURB: "VALE PARK", CASUALTIES: 2']
# ['SUBURB: "VALLEY  VIEW" , CASUALTIES: 0']
# ['SUBURB: "VALLEY VIEW", CASUALTIES: 6']
# ['SUBURB: "VEITCH" , CASUALTIES: 0']
# ['SUBURB: "VENUS BAY" , CASUALTIES: 0']
# ['SUBURB: "VERDUN", CASUALTIES: 1']
# ['SUBURB: "VERRAN" , CASUALTIES: 0']
# ['SUBURB: "VICTOR HARBOR", CASUALTIES: 3']
# ['SUBURB: "VINE VALE" , CASUALTIES: 0']
# ['SUBURB: "VIRGINIA", CASUALTIES: 3']
# ['SUBURB: "VISTA", CASUALTIES: 0']
# ['SUBURB: "VIVONNE BAY" , CASUALTIES: 0']
# ['SUBURB: "WADDIKEE" , CASUALTIES: 0']
# ['SUBURB: "WAIKERIE", CASUALTIES: 1']
# ['SUBURB: "WAITPINGA" , CASUALTIES: 0']
# ['SUBURB: "WALKER FLAT", CASUALTIES: 1']
# ['SUBURB: "WALKERVILLE", CASUALTIES: 2']
# ['SUBURB: "WALKLEY HEIGHTS", CASUALTIES: 3']
# ['SUBURB: "WALL FLAT" , CASUALTIES: 0']
# ['SUBURB: "WALLALA" , CASUALTIES: 0']
# ['SUBURB: "WALLAROO MINES", CASUALTIES: 0']
# ['SUBURB: "WALLAROO PLAIN" , CASUALTIES: 0']
# ['SUBURB: "WALLAROO", CASUALTIES: 2']
# ['SUBURB: "WALTOWA" , CASUALTIES: 0']
# ['SUBURB: "WAMI KATA" , CASUALTIES: 0']
# ['SUBURB: "WANBI" , CASUALTIES: 0']
# ['SUBURB: "WANDEARAH EAST" , CASUALTIES: 0']
# ['SUBURB: "WANDILO" , CASUALTIES: 0']
# ['SUBURB: "WANGARY" , CASUALTIES: 0']
# ['SUBURB: "WANGOLINA" , CASUALTIES: 0']
# ['SUBURB: "WANILLA" , CASUALTIES: 0']
# ['SUBURB: "WARBURTO" , CASUALTIES: 0']
# ['SUBURB: "WARD BELT", CASUALTIES: 1']
# ['SUBURB: "WARD HILL" , CASUALTIES: 0']
# ['SUBURB: "WARNERTOWN", CASUALTIES: 1']
# ['SUBURB: "WAROOKA" , CASUALTIES: 0']
# ['SUBURB: "WARRADALE", CASUALTIES: 6']
# ['SUBURB: "WARRAMBOO" , CASUALTIES: 0']
# ['SUBURB: "WASHPOOL" , CASUALTIES: 0']
# ['SUBURB: "WASLEYS" , CASUALTIES: 0']
# ['SUBURB: "WATCHMAN" , CASUALTIES: 0']
# ['SUBURB: "WATERFALL GULLY", CASUALTIES: 0']
# ['SUBURB: "WATERLOO CORNER", CASUALTIES: 6']
# ['SUBURB: "WATERLOO" , CASUALTIES: 0']
# ['SUBURB: "WATERVALE" , CASUALTIES: 0']
# ['SUBURB: "WATTLE FLAT" , CASUALTIES: 0']
# ['SUBURB: "WATTLE PARK" , CASUALTIES: 0']
# ['SUBURB: "WATTLE RANGE EAST" , CASUALTIES: 0']
# ['SUBURB: "WATTLE RANGE" , CASUALTIES: 0']
# ['SUBURB: "WAURALTEE" , CASUALTIES: 0']
# ['SUBURB: "WAYVILLE", CASUALTIES: 2']
# ['SUBURB: "WEEROONA ISLAND" , CASUALTIES: 0']
# ['SUBURB: "WEETULTA" , CASUALTIES: 0']
# ['SUBURB: "WELBOURN HILL" , CASUALTIES: 0']
# ['SUBURB: "WELLAND", CASUALTIES: 1']
# ['SUBURB: "WELLINGTON EAST" , CASUALTIES: 0']
# ['SUBURB: "WELLINGTON" , CASUALTIES: 0']
# ['SUBURB: "WEPAR" , CASUALTIES: 0']
# ['SUBURB: "WERTALOONA" , CASUALTIES: 0']
# ['SUBURB: "WEST BEACH", CASUALTIES: 0']
# ['SUBURB: "WEST CROYDON", CASUALTIES: 2']
# ['SUBURB: "WEST HINDMARSH", CASUALTIES: 3']
# ['SUBURB: "WEST LAKES SHORE" , CASUALTIES: 0']
# ['SUBURB: "WEST LAKES", CASUALTIES: 4']
# ['SUBURB: "WEST RANGE" , CASUALTIES: 0']
# ['SUBURB: "WEST RICHMOND", CASUALTIES: 1']
# ['SUBURB: "WESTALL", CASUALTIES: 1']
# ['SUBURB: "WESTBOURNE PARK", CASUALTIES: 1']
# ['SUBURB: "WESTERN FLAT" , CASUALTIES: 0']
# ['SUBURB: "WESTERN RIVER" , CASUALTIES: 0']
# ['SUBURB: "WESTLAKES" , CASUALTIES: 0']
# ['SUBURB: "WHITE HILL" , CASUALTIES: 0']
# ['SUBURB: "WHITE HUT" , CASUALTIES: 0']
# ['SUBURB: "WHITE SANDS" , CASUALTIES: 0']
# ['SUBURB: "WHITES FLAT", CASUALTIES: 0']
# ['SUBURB: "WHITES HILL" , CASUALTIES: 0']
# ['SUBURB: "WHITES RIVER" , CASUALTIES: 0']
# ['SUBURB: "WHITES VALLEY" , CASUALTIES: 0']
# ['SUBURB: "WHITWARTA" , CASUALTIES: 0']
# ['SUBURB: "WHYALLA BARSON" , CASUALTIES: 0']
# ['SUBURB: "WHYALLA JENKINS", CASUALTIES: 1']
# ['SUBURB: "WHYALLA NORRIE", CASUALTIES: 7']
# ['SUBURB: "WHYALLA PLAYFORD", CASUALTIES: 3']
# ['SUBURB: "WHYALLA STUART", CASUALTIES: 4']
# ['SUBURB: "WHYALLA", CASUALTIES: 1']
# ['SUBURB: "WHYTE YARCOWIE" , CASUALTIES: 0']
# ['SUBURB: "WIAWERA" , CASUALTIES: 0']
# ['SUBURB: "WIGLEY FLAT", CASUALTIES: 1']
# ['SUBURB: "WILD DOG VALLEY" , CASUALTIES: 0']
# ['SUBURB: "WILD HORSE PLAINS", CASUALTIES: 1']
# ['SUBURB: "WILGENA" , CASUALTIES: 0']
# ['SUBURB: "WILLALO" , CASUALTIES: 0']
# ['SUBURB: "WILLALOOKA" , CASUALTIES: 0']
# ['SUBURB: "WILLAMULKA", CASUALTIES: 1']
# ['SUBURB: "WILLASTON", CASUALTIES: 0']
# ['SUBURB: "WILLIAM CREEK" , CASUALTIES: 0']
# ['SUBURB: "WILLIAMSTOWN", CASUALTIES: 2']
# ['SUBURB: "WILLOCHRA" , CASUALTIES: 0']
# ['SUBURB: "WILLOUGHBY" , CASUALTIES: 0']
# ['SUBURB: "WILLOW CREEK" , CASUALTIES: 0']
# ['SUBURB: "WILLOW SPRINGS" , CASUALTIES: 0']
# ['SUBURB: "WILLOWIE" , CASUALTIES: 0']
# ['SUBURB: "WILLUNGA HILL" , CASUALTIES: 0']
# ['SUBURB: "WILLUNGA SOUTH" , CASUALTIES: 0']
# ['SUBURB: "WILLUNGA", CASUALTIES: 1']
# ['SUBURB: "WILLYAROO" , CASUALTIES: 0']
# ['SUBURB: "WILMINGTON", CASUALTIES: 4']
# ['SUBURB: "WINDSOR GARDENS", CASUALTIES: 2']
# ['SUBURB: "WINDSOR", CASUALTIES: 2']
# ['SUBURB: "WINGFIELD", CASUALTIES: 6']
# ['SUBURB: "WINKIE" , CASUALTIES: 0']
# ['SUBURB: "WINNININNIE" , CASUALTIES: 0']
# ['SUBURB: "WINNINOWIE", CASUALTIES: 0']
# ['SUBURB: "WINTINNA" , CASUALTIES: 0']
# ['SUBURB: "WINULTA" , CASUALTIES: 0']
# ['SUBURB: "WIRRABARA" , CASUALTIES: 0']
# ['SUBURB: "WIRRAMINNA" , CASUALTIES: 0']
# ['SUBURB: "WIRREGA" , CASUALTIES: 0']
# ['SUBURB: "WIRRINA COVE" , CASUALTIES: 0']
# ['SUBURB: "WIRRULLA" , CASUALTIES: 0']
# ['SUBURB: "WISANGER", CASUALTIES: 1']
# ['SUBURB: "WISTOW" , CASUALTIES: 0']
# ['SUBURB: "WITERA" , CASUALTIES: 0']
# ['SUBURB: "WITJIRA" , CASUALTIES: 0']
# ['SUBURB: "WOKURNA" , CASUALTIES: 0']
# ['SUBURB: "WOLSELEY" , CASUALTIES: 0']
# ['SUBURB: "WOMPINIE" , CASUALTIES: 0']
# ['SUBURB: "WONGULLA" , CASUALTIES: 0']
# ['SUBURB: "WONUARRA" , CASUALTIES: 0']
# ['SUBURB: "WOODCHESTER" , CASUALTIES: 0']
# ['SUBURB: "WOODCROFT" , CASUALTIES: 0']
# ['SUBURB: "WOODFORDE" , CASUALTIES: 0']
# ['SUBURB: "WOODLANE" , CASUALTIES: 0']
# ['SUBURB: "WOODLEIGH" , CASUALTIES: 0']
# ['SUBURB: "WOODS POINT" , CASUALTIES: 0']
# ['SUBURB: "WOODSIDE" , CASUALTIES: 0']
# ['SUBURB: "WOODVILLE GARDENS", CASUALTIES: 4']
# ['SUBURB: "WOODVILLE NORTH", CASUALTIES: 2']
# ['SUBURB: "WOODVILLE PARK " , CASUALTIES: 0']
# ['SUBURB: "WOODVILLE PARK", CASUALTIES: 2']
# ['SUBURB: "WOODVILLE SOUTH", CASUALTIES: 1']
# ['SUBURB: "WOODVILLE WEST", CASUALTIES: 3']
# ['SUBURB: "WOODVILLE", CASUALTIES: 1']
# ['SUBURB: "WOOL BAY" , CASUALTIES: 0']
# ['SUBURB: "WOOLPUNDA" , CASUALTIES: 0']
# ['SUBURB: "WOOLTANA" , CASUALTIES: 0']
# ['SUBURB: "WOOLUNDUNGA" , CASUALTIES: 0']
# ['SUBURB: "WOOMERA" , CASUALTIES: 0']
# ['SUBURB: "WORLDS END" , CASUALTIES: 0']
# ['SUBURB: "WORROLONG", CASUALTIES: 0']
# ['SUBURB: "WRATTONBULLY" , CASUALTIES: 0']
# ['SUBURB: "WUDINNA" , CASUALTIES: 0']
# ['SUBURB: "WUNKAR" , CASUALTIES: 0']
# ['SUBURB: "WYE" , CASUALTIES: 0']
# ['SUBURB: "WYNARKA" , CASUALTIES: 0']
# ['SUBURB: "WYNN VALE", CASUALTIES: 6']
# ['SUBURB: "YACKA" , CASUALTIES: 0']
# ['SUBURB: "YAHL", CASUALTIES: 1']
# ['SUBURB: "YALATA", CASUALTIES: 1']
# ['SUBURB: "YALLUNDA FLAT" , CASUALTIES: 0']
# ['SUBURB: "YAMBA", CASUALTIES: 1']
# ['SUBURB: "YANERBIE" , CASUALTIES: 0']
# ['SUBURB: "YANINEE" , CASUALTIES: 0']
# ['SUBURB: "YANKALILLA", CASUALTIES: 0']
# ['SUBURB: "YARDEA" , CASUALTIES: 0']
# ['SUBURB: "YARRAH" , CASUALTIES: 0']
# ['SUBURB: "YATALA VALE", CASUALTIES: 1']
# ['SUBURB: "YATINA" , CASUALTIES: 0']
# ['SUBURB: "YATTALUNGA", CASUALTIES: 3']
# ['SUBURB: "YELLABINNA" , CASUALTIES: 0']
# ['SUBURB: "YELTA" , CASUALTIES: 0']
# ['SUBURB: "YORKE VALLEY" , CASUALTIES: 0']
# ['SUBURB: "YORKETOWN", CASUALTIES: 2']
# ['SUBURB: "YOUNGHUSBAND" , CASUALTIES: 0']
# ['SUBURB: "YUMALI" , CASUALTIES: 0']
# ['SUBURB: "YUNDI" , CASUALTIES: 0']
# ['SUBURB: "YUNTA", CASUALTIES: 3']
# ['SUBURB: "YUNYARINYI" , CASUALTIES: 0']
# CPU times: user 40.5 s, sys: 6.49 s, total: 47 s
# Wall time: 45min 46s

# %% [markdown]
# ## [DataFrame]

# %%
# Import 5 CSV Files
Crash1 = spark.read.csv("2015_DATA_SA_Crash.csv")
Crash2 = spark.read.csv("2016_DATA_SA_Crash.csv")
Crash3 = spark.read.csv("2017_DATA_SA_Crash.csv")
Crash4 = spark.read.csv("2018_DATA_SA_Crash.csv")
Crash5 = spark.read.csv("2019_DATA_SA_Crash.csv")

# Sequentially merge Crash1, Crash3, Crash4, and then Crash5 into Crash1
CrashA = Crash1.union(Crash2)
CrashB = CrashA.union(Crash3)
CrashC = CrashB.union(Crash4)
Crash = CrashC.union(Crash5)

# Because of the merges, the header would have been repeated 4 times so we drop duplicates
CrashSchema = Crash.first()
Crash = Crash.filter(col("_c0")!="REPORT_ID")

# Rename columns
for i in range(0,len(Crash.columns)):
    Crash = Crash.withColumnRenamed(Crash.columns[i],CrashSchema[i])

# %%
# Import 5 CSV Files
Units1 = spark.read.csv("2015_DATA_SA_Units.csv")
Units2 = spark.read.csv("2016_DATA_SA_Units.csv")
Units3 = spark.read.csv("2017_DATA_SA_Units.csv")
Units4 = spark.read.csv("2018_DATA_SA_Units.csv")
Units5 = spark.read.csv("2019_DATA_SA_Units.csv")

# Sequentially merge Unit2, Unit3, Unit4, and then Unit5 into Unit1
UnitsA = Units1.union(Units2)
UnitsB = UnitsA.union(Units3)
UnitsC = UnitsB.union(Units4)
Units = UnitsC.union(Units5)

# Because of the merges, the header would have been repeated 4 times so we drop duplicates
UnitsSchema = Units.first()
Units = Units.filter(col("_c0")!="REPORT_ID")

# Rename columns
for i in range(0,len(Units.columns)):
    Units = Units.withColumnRenamed(Units.columns[i],UnitsSchema[i])

# %% [markdown]
# ## [DataFrame] 2.4.1

# %%
# %%time

# Join the DataFrames, Filter for Suburb, Filter out invalid Ages, Filter out NULL Licence Types
# Format the Date information correctly, Include all other relevant columns, rename, and show
Crash241 = Crash\
.join(Units,'REPORT_ID',how = 'inner')\
.filter(col('Suburb') == 'ADELAIDE')\
.filter(col('Age') != 'XXX')\
.filter(col('Licence Type').isNotNull())\
.withColumn('YearMonthDay',(concat(col("Year"), lit("-"), col("Month"), lit("-"), col("Day"))))\
.select(['YearMonthDay','Time','Total Cas','Sex','Age','Licence Type'])\
.withColumnRenamed('YearMonthDay','Date')\
.show()
# Out:
# +--------------------+--------+---------+------+---+--------------+
# |                Date|    Time|Total Cas|   Sex|Age|  Licence Type|
# +--------------------+--------+---------+------+---+--------------+
# |2015-January-Tuesday|08:30 am|        0|  Male|030|          Full|
# |2015-January-Tuesday|08:30 am|        0|  Male|042|          Full|
# |2015-January-Thur...|06:30 pm|        0|  Male|025|          Full|
# |2015-January-Thur...|06:30 pm|        0|  Male|055|          Full|
# | 2015-January-Friday|05:00 pm|        0|  Male|028|          Full|
# | 2015-January-Friday|06:10 pm|        1|Female|035|          Full|
# | 2015-January-Friday|06:10 pm|        1|Female|037|          Full|
# | 2015-January-Friday|05:00 pm|        0|  Male|041|          Full|
# |2015-January-Wedn...|09:45 am|        0|Female|058|          Full|
# |2015-January-Satu...|01:55 pm|        0|  Male|025|          Full|
# |2015-February-Tue...|04:20 pm|        1|Female|040|          Full|
# |2015-February-Tue...|04:20 pm|        1|Female|054|          Full|
# |2015-February-Thu...|02:40 pm|        0|  Male|057|          Full|
# |2015-February-Thu...|02:40 pm|        0|Female|041|          Full|
# |2015-February-Thu...|04:15 pm|        0|Female|072|          Full|
# |2015-February-Friday|08:00 pm|        1|  Male|020|Provisional 1 |
# |   2015-March-Friday|06:45 pm|        0|Female|020| Provisional 2|
# |   2015-March-Sunday|11:00 am|        0|Female|058|          Full|
# | 2015-March-Thursday|08:00 am|        0|  Male|084|          Full|
# |  2015-March-Tuesday|08:26 am|        0|Female|051|          Full|
# +--------------------+--------+---------+------+---+--------------+
# only showing top 20 rows
#
# CPU times: user 8.01 ms, sys: 2.58 ms, total: 10.6 ms
# Wall time: 938 ms

# %% [markdown]
# ## [DataFrame] 2.4.2

# %%
# %%time

# Join the DataFrames, Filter for Unlicenced Licence Types
# Group by Suburb, Aggregating the sum of Casualties and renaming the aggregated column
Crash242 = Crash\
.join(Units,'REPORT_ID',how = 'inner')\
.filter(col('Licence Type')=='Unlicenced')\
.groupBy('Suburb')\
.agg({'Total Cas': 'sum'})\
.withColumnRenamed('sum(Total Cas)','Casualties')

# Sort the returned DataFrame by Casualties in descending order
Crash242\
.orderBy(Crash242['Casualties']\
.desc())\
.show()
# Out:
# +---------------+----------+
# |         Suburb|Casualties|
# +---------------+----------+
# |       ADELAIDE|      19.0|
# |      SALISBURY|      18.0|
# |      DRY CREEK|      18.0|
# | SALISBURY EAST|      16.0|
# |       PROSPECT|      14.0|
# | NORTH ADELAIDE|      13.0|
# |        ENFIELD|      12.0|
# |   ANDREWS FARM|      12.0|
# |SALISBURY SOUTH|      11.0|
# |SALISBURY DOWNS|      11.0|
# |   BEDFORD PARK|      11.0|
# |     INGLE FARM|      11.0|
# |   MOUNT BARKER|      10.0|
# |     MUNNO PARA|      10.0|
# |  MORPHETT VALE|      10.0|
# |SALISBURY PLAIN|      10.0|
# | ELIZABETH PARK|      10.0|
# |   MAWSON LAKES|      10.0|
# |         BURTON|      10.0|
# |    HOLDEN HILL|       9.0|
# +---------------+----------+
# only showing top 20 rows
#
# CPU times: user 5.06 ms, sys: 1.91 ms, total: 6.97 ms
# Wall time: 1.71 s

# %% [markdown]
# ## [Spark SQL]

# %%
# 'Cast' the DataFrames as temporary views to use SQL on
Units.createOrReplaceTempView("Units")
Crash.createOrReplaceTempView("Crash")

# %% [markdown]
# ## [Spark SQL] 2.4.1

# %%
# %%time

# SELECT the columns to take (creating the Date column in the process)
# FROM Crash JOIN Units where the Suburb is 'Adelaide'
sql241 = spark.sql\
("SELECT Year || '-' || Month || '-' || Day as Date, Time, \
`Total Cas`, Sex, Age, `Licence Type` \
FROM Crash INNER JOIN Units ON Crash.REPORT_ID = Units.REPORT_ID \
WHERE Crash.Suburb='ADELAIDE'")\
.collect()
# Out:
# CPU times: user 20.6 ms, sys: 1.07 ms, total: 21.7 ms
# Wall time: 1.05 s

# %%
# Represent the DataFrame as a Pandas DataFrame for better readability
df = pd.DataFrame(sql241)

# Rename the columns
df = df.rename(columns={0: "Date", 1: "Time", 2: "Casualties", 3:"Gender", 4:"Age", 5:"Licence Type"})
df
# Out:
#                        Date      Time Casualties  Gender  Age Licence Type
# 0      2015-January-Tuesday  08:30 am          0    Male  030         Full
# 1      2015-January-Tuesday  08:30 am          0    Male  042         Full
# 2     2015-January-Thursday  06:30 pm          0    Male  025         Full
# 3     2015-January-Thursday  06:30 pm          0    Male  055         Full
# 4       2015-January-Friday  05:00 pm          0    Male  028         Full
# ...                     ...       ...        ...     ...  ...          ...
# 6305   2019-December-Sunday  09:19 am          0    Male  057         Full
# 6306  2019-December-Tuesday  03:40 pm          0    Male  065         Full
# 6307  2019-December-Tuesday  03:40 pm          0  Female  056         Full
# 6308  2019-December-Tuesday  03:00 pm          0    Male  026         Full
# 6309  2019-December-Tuesday  03:00 pm          0  Female  034         Full
#
# [6310 rows x 6 columns]

# %% [markdown]
# ## [Spark SQL] 2.4.2

# %%
# %%time

# SELECT the columns, specifying to  to take FROM Crash JOIN Units
# WHERE Licence Type is Unlicenced
sql242 = spark.sql("SELECT  Suburb, SUM(`Total Cas`) AS `Casualties` \
FROM Crash INNER JOIN Units ON Crash.REPORT_ID = Units.REPORT_ID \
WHERE Units.`Licence Type`='Unlicenced' \
GROUP BY Suburb \
ORDER BY CASUALTIES DESC") \
.collect()
# Out:
# CPU times: user 4.55 ms, sys: 1.81 ms, total: 6.35 ms
# Wall time: 2.17 s

# %%
# Represent the DataFrame as a Pandas DataFrame for better readability
df = pd.DataFrame(sql242)

# Rename the columns
df = df.rename(columns={0: "Suburb", 1: "Casualties"})
df
# Out:
#              Suburb  Casualties
# 0          ADELAIDE        19.0
# 1         DRY CREEK        18.0
# 2         SALISBURY        18.0
# 3    SALISBURY EAST        16.0
# 4          PROSPECT        14.0
# ..              ...         ...
# 629   REEVES PLAINS         0.0
# 630          FULHAM         0.0
# 631          STRUAN         0.0
# 632        BIRDWOOD         0.0
# 633   CLARENCE PARK         0.0
#
# [634 rows x 2 columns]
